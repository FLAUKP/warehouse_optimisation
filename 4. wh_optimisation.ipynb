# %%
# 1, connect to postgreSQL
from sqlalchemy import create_engine
engine = create_engine('postgresql://postgres:BIDA123@localhost/warehouseopt_A')

# %%
# 2, create SKU master list
# create SKU number, dimensions, standard picking time per unit 

import pandas as pd
import numpy as np
import random
from random import randrange


sku = 1
skulist = []

for i in range(200):
    skulist.append('AA'+str(sku).zfill(4))
    sku+=1
np.random.seed(1)
skulist = pd.DataFrame(skulist)
skulist.columns=['sku_id']
skulist['sku_length'] = np.round(np.random.normal(40,5,200))
skulist['sku_width'] = np.round(np.random.normal(35,5,200))
skulist['sku_height'] = np.round(np.random.normal(30,3,200))
skulist['sku_weight'] = np.round(np.random.normal(7,1,200))
skulist['standard_time'] = np.round(np.random.normal(35,2,200))

print(skulist)

# converting list to set
#skulist.to_csv("dropzone_sku.csv",index=False)
skulist.to_sql("dropzone_sku",engine,if_exists='replace',index=False)

# %%
# 3, create orders, each with skus and qty, daily for 30 days

import pandas as pd
import numpy as np
import random
from datetime import date, timedelta, datetime
from random import randrange

random.seed(1)
np.random.seed(1)

#skus = pd.read_csv('dropzone_sku.csv')
skus = pd.read_sql('SELECT sku_id FROM dropzone_sku', con = engine)
ssku = set(skus['sku_id'])

# create list of days in month

sdate = datetime(2021, 6, 1, 0, 1, 22)   # start date
edate = datetime(2021, 6, 30, 0, 1, 22)   # end date
date_modified = sdate
date_in_mth = [sdate.strftime("%d/%m/%Y %H:%M:%S")]


while date_modified < edate:
    date_modified += timedelta(days=1) 
    date_in_mth.append(date_modified.strftime("%d/%m/%Y %H:%M:%S"))

print(date_in_mth, '\n')

# create orders for each day in month base on Poisson Distribution

nr_order_daily_list = [np.random.poisson(27) for i in range(30)]

print(nr_order_daily_list, '\n')


order_table = pd.DataFrame(columns = ['date', 'order_id', 'sku_id', 'qty'])
order_id = 1

for d, k in zip(date_in_mth, nr_order_daily_list):          # k = total orders per day
    print(d, k)
    for m in range(k):                                      # each loop will create list of SKUs per order
        nr_sku_per_order = np.random.poisson(5)
        order_sku_list = random.sample(ssku, nr_sku_per_order)
        order_date = datetime.strptime(d, "%d/%m/%Y %H:%M:%S") + \
            timedelta(hours=randrange(24)) + timedelta(minutes=randrange(60))
        for sku in order_sku_list:                          # each loop will create qty (pcs) per sku 
            nr_pcs_per_sku = int(np.random.normal(7,1))        # average 7 pcs per sku, std dev = 1
            order_table = order_table.append({'date': order_date, \
                'order_id': 'SO'+str(order_id).zfill(5), 'sku_id': sku, 'qty': nr_pcs_per_sku}, ignore_index=True)
        order_id +=1

print(order_table.tail())

#order_table.to_csv('dropzone_order.csv', index=False)
order_table.to_sql("dropzone_order",engine,if_exists='replace',index=False)

# %%
# 4, Batching the orders

import pandas as pd
import datetime 
import numpy as np

#df = pd.read_csv('dropzone_order.csv')
df = pd.read_sql('SELECT * FROM dropzone_order', con = engine)

df['date'] = pd.to_datetime(df['date'],format="%Y-%m-%d")
df['date_hour'] = pd.DatetimeIndex(df['date']).hour
 
#df['date_1']= pd.to_datetime(df['Date']).dt.normalize()
print(df)
        
#create a list of condition for batching
roundingtime = [
        (df['date_hour'] >= 0) & (df['date_hour'] < 8 ),
        (df['date_hour'] >= 15) & (df['date_hour'] < 24 ),
        (df['date_hour'] >= 8) & (df['date_hour'] < 10 ),
        (df['date_hour'] >= 10 ) & (df['date_hour'] < 13 ),
        (df['date_hour'] >= 13) & (df['date_hour'] < 15 )
     ]

values =[8, 8, 10, 13, 15]
         
df['timestamp'] = np.select(roundingtime,values)

#create a list of condition for next day 

nextday = [
        (df['date_hour'] >= 15) & (df['date_hour'] < 24 ),
        (df['date_hour'] >= 0) & (df['date_hour'] < 15 )
        ]

date = [df['date'].dt.date + datetime.timedelta(days=1),df['date'].dt.date]
df['date_1'] = np.select(nextday,date)

# combine date and time
df['batch_date'] = pd.to_datetime(df.date_1) + df.timestamp.astype('timedelta64[h]')
df.reset_index(drop=True, inplace=True)
df['task_id'] = 1 + df.index
print(df)

df1 = df.drop(['timestamp','date_1','date_hour'], axis=1)
print(df1.dtypes)
#df1.to_csv("dropzone_batch_order_table.csv")
df1.to_sql("dropzone_batch_order",engine,if_exists='replace',index=False)

# %%
# 5, create worker list
from faker import Faker
import pandas as pd
import numpy as np

num_worker = 20

faker = Faker()
Faker.seed(4321)
np.random.seed(1)

df = []
serial=1
for n in range(20):
    df.append({'worker_id': "W" + str(serial).zfill(3), 'name':faker.name()})
    serial+=1

df = pd.DataFrame(df)
df = df[['worker_id','name']]
df['salaryperhr']= np.random.randint(7,14,20) 

df1 = df[:num_worker]

print(df1)
 
# df1.to_sql('dropzone_workers_all', engine, if_exists='replace',index=False) # insert one_time fixed table for all workers to postgresql
df1.to_sql('dropzone_workers', engine, if_exists='replace',index=False) # insert table to postgresql
# Out:
#    worker_id                   name  salaryperhr
# 0       W001            Jason Brown           12
# 1       W002            Jacob Stein           10
# 2       W003             Cody Brown           11
# 3       W004          Larry Morales            7
# 4       W005      Jessica Hendricks            8
# 5       W006            Brian Moore           10
# 6       W007            Scott Baker           12
# 7       W008           Ruth Hoffman            7
# 8       W009          Daniel George            7
# 9       W010            David Moody            8
# 10      W011          Brian Maxwell           11
# 11      W012            Cory Cooper           12
# 12      W013          Morgan Foster           11
# 13      W014         James Sandoval           13
# 14      W015           Brian Lester            8
# 15      W016             Anne Davis            9
# 16      W017  Miss Amanda Harris MD           11
# 17      W018               Amy Dunn           13
# 18      W019              Brian Lee           12
# 19      W020         Kimberly Pratt            9

# %%
# 6, create worker-SKU relationship
# each relation represent time taken to pick 1 piece of SKU

import csv
import pandas as pd
import numpy as np

col_list = ['sku_id', 'standard_time']
#skus = pd.read_csv('dropzone_sku.csv', usecols=col_list)
skus = pd.read_sql('SELECT sku_id, standard_time FROM dropzone_sku', con = engine)

#workers = pd.read_csv('dropzone_workers.csv', usecols=['worker_id'])
workers = pd.read_sql('SELECT worker_id FROM dropzone_workers', con = engine)

sku_list = skus.values.tolist()
workers_list = workers['worker_id'].to_list()

productivity = []

# workers_productivity = pd.DataFrame(workers_productivity, columns=['sku', 'std_mins', 'worker', 'avg_time'])
np.random.seed(1)
for sku, mins in sku_list:
    for worker in workers_list:
        avg_time = int(np.random.normal(mins,3))
        productivity.append({'sku_id': sku, 'worker': worker, 'avg_time': avg_time})

df = pd.DataFrame(productivity)

print(df)

#df.to_csv("dropzone_worker_sku_proficiency.csv",index=False)
df.to_sql("dropzone_worker_sku_proficiency", engine, if_exists='replace', index=False)
# Out:
#       sku_id worker  avg_time
# 0     AA0001   W001        41
# 1     AA0001   W002        35
# 2     AA0001   W003        35
# 3     AA0001   W004        33
# 4     AA0001   W005        39
# ...      ...    ...       ...
# 2395  AA0200   W008        46
# 2396  AA0200   W009        39
# 2397  AA0200   W010        30
# 2398  AA0200   W011        33
# 2399  AA0200   W012        37
#
# [2400 rows x 3 columns]

# %%
# 7, breakdown total month orders into daily batches 
# create sku-worker matrix for optimisation assignment
import csv
import pandas as pd
import datetime
import numpy as np

#workers_df = pd.read_csv("dropzone_worker_sku_proficiency.csv")
workers_df = pd.read_sql('SELECT * from dropzone_worker_sku_proficiency', con = engine)
print(workers_df.head(), '\n')

# col_list = ['date', 'sku_id', 'qty']
#batch_df = pd.read_csv("dropzone_batch_order_table.csv", usecols=col_list)
batch_df = pd.read_sql('SELECT date, sku_id, qty from dropzone_batch_order', con = engine)
print(batch_df.head(), '\n')

# Batch 1
batch1 = batch_df.loc[(batch_df['date'] >= "2021-06-01 00:00:00") & (batch_df['date'] < "2021-06-01 08:00:00")] # Tue - Tue
batch1agg = batch1[['sku_id', 'qty']].groupby(['sku_id'], sort=True).sum()
print(batch1agg.head(), '\n')

productivity1 = workers_df.join(batch1agg, on='sku_id', how='left')  # .set_index('sku_id')
print(productivity1.head(), '\n')

productivity1['avg_time_add'] = productivity1['avg_time'] + productivity1['qty'] * 1
workers_productivity1 = productivity1.pivot(index='worker', columns='sku_id', values='avg_time_add')

# print(workers_productivity, '\n')
# print(workers_productivity.values.tolist())

# workers_productivity1.to_csv("dropzone_workers_productivity1.csv")
workers_productivity1.to_sql("processed_workers_productivity1",engine,if_exists='replace',index=False)


# Batch 2

batch2 = batch_df.loc[(batch_df['date'] >= "2021-06-01 08:00:00") & (batch_df['date'] < "2021-06-02 08:00:00")] # Tue - Wed
batch2agg = batch2[['sku_id', 'qty']].groupby(['sku_id'], sort=True).sum()

productivity2 = workers_df.join(batch2agg, on='sku_id', how='left')  # .set_index('sku_id')
productivity2['avg_time_add'] = productivity2['avg_time'] + productivity2['qty'] * 1

workers_productivity2 = productivity2.pivot(index='worker', columns='sku_id', values='avg_time_add')
# workers_productivity2.to_csv("dropzone_workers_productivity2.csv")
workers_productivity2.to_sql("processed_workers_productivity2",engine,if_exists='replace',index=False)


# Batch 3
batch3 = batch_df.loc[(batch_df['date'] >= "2021-06-02 08:00:00") & (batch_df['date'] < "2021-06-03 08:00:00")] # Wed - Thu
batch3agg = batch3[['sku_id', 'qty']].groupby(['sku_id'], sort=True).sum()

productivity3 = workers_df.join(batch3agg, on='sku_id', how='left')  # .set_index('sku_id')
productivity3['avg_time_add'] = productivity3['avg_time'] + productivity3['qty'] * 1

workers_productivity3 = productivity3.pivot(index='worker', columns='sku_id', values='avg_time_add')
# workers_productivity3.to_csv("dropzone_workers_productivity3.csv")
workers_productivity3.to_sql("processed_workers_productivity3",engine,if_exists='replace',index=False)


# Batch 4
batch4 = batch_df.loc[(batch_df['date'] >= "2021-06-03 08:00:00") & (batch_df['date'] < "2021-06-04 08:00:00")] # Thu - Fri
batch4agg = batch4[['sku_id', 'qty']].groupby(['sku_id'], sort=True).sum()

productivity4 = workers_df.join(batch4agg, on='sku_id', how='left')  # .set_index('sku_id')
productivity4['avg_time_add'] = productivity4['avg_time'] + productivity4['qty'] * 1

workers_productivity4 = productivity4.pivot(index='worker', columns='sku_id', values='avg_time_add')
# workers_productivity4.to_csv("dropzone_workers_productivity4.csv")
workers_productivity4.to_sql("processed_workers_productivity4",engine,if_exists='replace',index=False)


# Batch 5
batch5 = batch_df.loc[(batch_df['date'] >= "2021-06-04 08:00:00") & (batch_df['date'] < "2021-06-07 08:00:00")] # Fri - Mon
batch5agg = batch5[['sku_id', 'qty']].groupby(['sku_id'], sort=True).sum()

productivity5 = workers_df.join(batch5agg, on='sku_id', how='left')  # .set_index('sku_id')
productivity5['avg_time_add'] = productivity5['avg_time'] + productivity5['qty'] * 1

workers_productivity5 = productivity5.pivot(index='worker', columns='sku_id', values='avg_time_add')
# workers_productivity5.to_csv("dropzone_workers_productivity5.csv")
workers_productivity5.to_sql("processed_workers_productivity5",engine,if_exists='replace',index=False)


# Batch 6
batch6 = batch_df.loc[(batch_df['date'] >= "2021-06-07 08:00:00") & (batch_df['date'] < "2021-06-08 08:00:00")] # Mon - Tue
batch6agg = batch6[['sku_id', 'qty']].groupby(['sku_id'], sort=True).sum()

productivity6 = workers_df.join(batch6agg, on='sku_id', how='left')  # .set_index('sku_id')
productivity6['avg_time_add'] = productivity6['avg_time'] + productivity6['qty'] * 1

workers_productivity6 = productivity6.pivot(index='worker', columns='sku_id', values='avg_time_add')
# workers_productivity6.to_csv("dropzone_workers_productivity6.csv")
workers_productivity6.to_sql("processed_workers_productivity6",engine,if_exists='replace',index=False)


# Batch 7
batch7 = batch_df.loc[(batch_df['date'] >= "2021-06-08 08:00:00") & (batch_df['date'] < "2021-06-09 08:00:00")] # Tue - Wed
batch7agg = batch7[['sku_id', 'qty']].groupby(['sku_id'], sort=True).sum()

productivity7 = workers_df.join(batch7agg, on='sku_id', how='left')  # .set_index('sku_id')
productivity7['avg_time_add'] = productivity7['avg_time'] + productivity7['qty'] * 1

workers_productivity7 = productivity7.pivot(index='worker', columns='sku_id', values='avg_time_add')
# workers_productivity7.to_csv("dropzone_workers_productivity7.csv")
workers_productivity7.to_sql("processed_workers_productivity7",engine,if_exists='replace',index=False)


# Batch 8
batch8 = batch_df.loc[(batch_df['date'] >= "2021-06-09 08:00:00") & (batch_df['date'] < "2021-06-10 08:00:00")] # Wed - Thu
batch8agg = batch8[['sku_id', 'qty']].groupby(['sku_id'], sort=True).sum()

productivity8 = workers_df.join(batch8agg, on='sku_id', how='left')  # .set_index('sku_id')
productivity8['avg_time_add'] = productivity8['avg_time'] + productivity8['qty'] * 1

workers_productivity8 = productivity8.pivot(index='worker', columns='sku_id', values='avg_time_add')
# workers_productivity8.to_csv("dropzone_workers_productivity8.csv")
workers_productivity8.to_sql("processed_workers_productivity8",engine,if_exists='replace',index=False)


# Batch 9
batch9 = batch_df.loc[(batch_df['date'] >= "2021-06-10 08:00:00") & (batch_df['date'] < "2021-06-11 08:00:00")] # Thu - Fri
batch9agg = batch9[['sku_id', 'qty']].groupby(['sku_id'], sort=True).sum()

productivity9 = workers_df.join(batch9agg, on='sku_id', how='left')  # .set_index('sku_id')
productivity9['avg_time_add'] = productivity9['avg_time'] + productivity9['qty'] * 1

workers_productivity9 = productivity9.pivot(index='worker', columns='sku_id', values='avg_time_add')
# workers_productivity9.to_csv("dropzone_workers_productivity9.csv")
workers_productivity9.to_sql("processed_workers_productivity9",engine,if_exists='replace',index=False)


# Batch 10
batch10 = batch_df.loc[(batch_df['date'] >= "2021-06-11 08:00:00") & (batch_df['date'] < "2021-06-14 08:00:00")] # Fri - Mon
batch10agg = batch10[['sku_id', 'qty']].groupby(['sku_id'], sort=True).sum()

productivity10 = workers_df.join(batch10agg, on='sku_id', how='left')  # .set_index('sku_id')
productivity10['avg_time_add'] = productivity10['avg_time'] + productivity10['qty'] * 1

workers_productivity10 = productivity10.pivot(index='worker', columns='sku_id', values='avg_time_add')
# workers_productivity10.to_csv("dropzone_workers_productivity10.csv")
workers_productivity10.to_sql("processed_workers_productivity10",engine,if_exists='replace',index=False)


# Batch 11
batch11 = batch_df.loc[(batch_df['date'] >= "2021-06-14 08:00:00") & (batch_df['date'] < "2021-06-15 08:00:00")] # Mon - Tue
batch11agg = batch11[['sku_id', 'qty']].groupby(['sku_id'], sort=True).sum()

productivity11 = workers_df.join(batch11agg, on='sku_id', how='left')  # .set_index('sku_id')
productivity11['avg_time_add'] = productivity11['avg_time'] + productivity11['qty'] * 1

workers_productivity11 = productivity11.pivot(index='worker', columns='sku_id', values='avg_time_add')
# workers_productivity11.to_csv("dropzone_workers_productivity11.csv")
workers_productivity11.to_sql("processed_workers_productivity11",engine,if_exists='replace',index=False)


# Batch 12
batch12 = batch_df.loc[(batch_df['date'] >= "2021-06-15 08:00:00") & (batch_df['date'] < "2021-06-16 08:00:00")] # Tue - Wed
batch12agg = batch12[['sku_id', 'qty']].groupby(['sku_id'], sort=True).sum()

productivity12 = workers_df.join(batch12agg, on='sku_id', how='left')  # .set_index('sku_id')
productivity12['avg_time_add'] = productivity12['avg_time'] + productivity12['qty'] * 1

workers_productivity12 = productivity12.pivot(index='worker', columns='sku_id', values='avg_time_add')
# workers_productivity12.to_csv("dropzone_workers_productivity12.csv")
workers_productivity12.to_sql("processed_workers_productivity12",engine,if_exists='replace',index=False)


# Batch 13
batch13 = batch_df.loc[(batch_df['date'] >= "2021-06-16 08:00:00") & (batch_df['date'] < "2021-06-17 08:00:00")] # Wed - Thu
batch13agg = batch13[['sku_id', 'qty']].groupby(['sku_id'], sort=True).sum()

productivity13 = workers_df.join(batch13agg, on='sku_id', how='left')  # .set_index('sku_id')
productivity13['avg_time_add'] = productivity13['avg_time'] + productivity13['qty'] * 1

workers_productivity13 = productivity13.pivot(index='worker', columns='sku_id', values='avg_time_add')
# workers_productivity13.to_csv("dropzone_workers_productivity13.csv")
workers_productivity13.to_sql("processed_workers_productivity13",engine,if_exists='replace',index=False)


# Batch 14
batch14 = batch_df.loc[(batch_df['date'] >= "2021-06-17 08:00:00") & (batch_df['date'] < "2021-06-18 08:00:00")] # Thu - Fri
batch14agg = batch14[['sku_id', 'qty']].groupby(['sku_id'], sort=True).sum()

productivity14 = workers_df.join(batch14agg, on='sku_id', how='left')  # .set_index('sku_id')
productivity14['avg_time_add'] = productivity14['avg_time'] + productivity14['qty'] * 1

workers_productivity14 = productivity14.pivot(index='worker', columns='sku_id', values='avg_time_add')
# workers_productivity14.to_csv("dropzone_workers_productivity14.csv")
workers_productivity14.to_sql("processed_workers_productivity14",engine,if_exists='replace',index=False)


# Batch 15
batch15 = batch_df.loc[(batch_df['date'] >= "2021-06-18 08:00:00") & (batch_df['date'] < "2021-06-21 08:00:00")] # Fri - Mon
batch15agg = batch15[['sku_id', 'qty']].groupby(['sku_id'], sort=True).sum()

productivity15 = workers_df.join(batch15agg, on='sku_id', how='left')  # .set_index('sku_id')
productivity15['avg_time_add'] = productivity15['avg_time'] + productivity15['qty'] * 1

workers_productivity15 = productivity15.pivot(index='worker', columns='sku_id', values='avg_time_add')
# workers_productivity15.to_csv("dropzone_workers_productivity15.csv")
workers_productivity15.to_sql("processed_workers_productivity15",engine,if_exists='replace',index=False)


# Batch 16
batch16 = batch_df.loc[(batch_df['date'] >= "2021-06-21 08:00:00") & (batch_df['date'] < "2021-06-22 08:00:00")] # Mon - Tue
batch16agg = batch16[['sku_id', 'qty']].groupby(['sku_id'], sort=True).sum()

productivity16 = workers_df.join(batch16agg, on='sku_id', how='left')  # .set_index('sku_id')
productivity16['avg_time_add'] = productivity16['avg_time'] + productivity16['qty'] * 1

workers_productivity16 = productivity16.pivot(index='worker', columns='sku_id', values='avg_time_add')
# workers_productivity16.to_csv("dropzone_workers_productivity16.csv")
workers_productivity16.to_sql("processed_workers_productivity16",engine,if_exists='replace',index=False)


# Batch 17
batch17 = batch_df.loc[(batch_df['date'] >= "2021-06-22 08:00:00") & (batch_df['date'] < "2021-06-23 08:00:00")] # Tue - Wed
batch17agg = batch17[['sku_id', 'qty']].groupby(['sku_id'], sort=True).sum()

productivity17 = workers_df.join(batch17agg, on='sku_id', how='left')  # .set_index('sku_id')
productivity17['avg_time_add'] = productivity17['avg_time'] + productivity17['qty'] * 1

workers_productivity17 = productivity17.pivot(index='worker', columns='sku_id', values='avg_time_add')
# workers_productivity17.to_csv("dropzone_workers_productivity17.csv")
workers_productivity17.to_sql("processed_workers_productivity17",engine,if_exists='replace',index=False)


# Batch 18
batch18 = batch_df.loc[(batch_df['date'] >= "2021-06-23 08:00:00") & (batch_df['date'] < "2021-06-24 08:00:00")] # Wed - Thu
batch18agg = batch18[['sku_id', 'qty']].groupby(['sku_id'], sort=True).sum()

productivity18 = workers_df.join(batch18agg, on='sku_id', how='left')  # .set_index('sku_id')
productivity18['avg_time_add'] = productivity18['avg_time'] + productivity18['qty'] * 1

workers_productivity18 = productivity18.pivot(index='worker', columns='sku_id', values='avg_time_add')
# workers_productivity18.to_csv("dropzone_workers_productivity18.csv")
workers_productivity18.to_sql("processed_workers_productivity18",engine,if_exists='replace',index=False)


# Batch 19
batch19 = batch_df.loc[(batch_df['date'] >= "2021-06-24 08:00:00") & (batch_df['date'] < "2021-06-25 08:00:00")] # Thu - Fri
batch19agg = batch19[['sku_id', 'qty']].groupby(['sku_id'], sort=True).sum()

productivity19 = workers_df.join(batch19agg, on='sku_id', how='left')  # .set_index('sku_id')
productivity19['avg_time_add'] = productivity19['avg_time'] + productivity19['qty'] * 1

workers_productivity19 = productivity19.pivot(index='worker', columns='sku_id', values='avg_time_add')
# workers_productivity19.to_csv("dropzone_workers_productivity19.csv")
workers_productivity19.to_sql("processed_workers_productivity19",engine,if_exists='replace',index=False)


# Batch 20
batch20 = batch_df.loc[(batch_df['date'] >= "2021-06-25 08:00:00") & (batch_df['date'] < "2021-06-28 08:00:00")] # Fri - Mon
batch20agg = batch20[['sku_id', 'qty']].groupby(['sku_id'], sort=True).sum()

productivity20 = workers_df.join(batch20agg, on='sku_id', how='left')  # .set_index('sku_id')
productivity20['avg_time_add'] = productivity20['avg_time'] + productivity20['qty'] * 1

workers_productivity20 = productivity20.pivot(index='worker', columns='sku_id', values='avg_time_add')
#workers_productivity20.to_csv("dropzone_workers_productivity20.csv")
workers_productivity20.to_sql("processed_workers_productivity20",engine,if_exists='replace',index=False)


# Batch 21
batch21 = batch_df.loc[(batch_df['date'] >= "2021-06-28 08:00:00") & (batch_df['date'] < "2021-06-29 08:00:00")] # Mon - Tue
batch21agg = batch21[['sku_id', 'qty']].groupby(['sku_id'], sort=True).sum()

productivity21 = workers_df.join(batch21agg, on='sku_id', how='left')  # .set_index('sku_id')
productivity21['avg_time_add'] = productivity21['avg_time'] + productivity21['qty'] * 1

workers_productivity21 = productivity21.pivot(index='worker', columns='sku_id', values='avg_time_add')
# workers_productivity21.to_csv("dropzone_workers_productivity21.csv")
workers_productivity21.to_sql("processed_workers_productivity21",engine,if_exists='replace',index=False)


# Batch 22
batch22 = batch_df.loc[(batch_df['date'] >= "2021-06-29 08:00:00") & (batch_df['date'] < "2021-06-30 08:00:00")] # Tue - Wed
batch22agg = batch22[['sku_id', 'qty']].groupby(['sku_id'], sort=True).sum()

productivity22 = workers_df.join(batch22agg, on='sku_id', how='left')  # .set_index('sku_id')
productivity22['avg_time_add'] = productivity22['avg_time'] + productivity22['qty'] * 1

workers_productivity22 = productivity22.pivot(index='worker', columns='sku_id', values='avg_time_add')
# workers_productivity22.to_csv("dropzone_workers_productivity22.csv")
workers_productivity22.to_sql("processed_workers_productivity22",engine,if_exists='replace',index=False)


# # sort by date and shift
# ml_df1 = ml_df[(ml_df['batch_date'] >= '2021-6-1 08:00:00') & (ml_df['batch_date'] < '2021-6-1 10:00:00')] 

# print(ml_df1)


# ml_df = df1.join(workers_df.set_index("sku_id"), on="sku_id", how="left")  # join table 

# ml_df['avg_time_add'] = ml_df['avg_time'] + ml_df['qty'] * 1  

# ml_df2 = (ml_df1.loc[:,['task_id','worker','avg_time_add']])
# print(ml_df2)
# #ml_df1.to_csv('test.csv',index=False)

# #workers_productivity_qty = ml_df2.pivot(index='worker', columns='sku_id', values='avg_time_add')

# # pivot with duplicate index
# workers_productivity_qty = ml_df1.groupby(['worker','task_id'],sort=False)['avg_time_add'].first().unstack('task_id')

# print(workers_productivity_qty)

# workers_productivity_qty.to_csv("ml_assignment.csv", index=False, header=False)
# #workers_productivity_qty.to_csv("ml_assignment1.csv")
# Out:
#    sku_id worker  avg_time
# 0  AA0001   W001        41
# 1  AA0001   W002        35
# 2  AA0001   W003        35
# 3  AA0001   W004        33
# 4  AA0001   W005        39
#
#                  date  sku_id  qty
# 0 2021-06-01 15:42:22  AA0157    9
# 1 2021-06-01 15:42:22  AA0094    5
# 2 2021-06-01 15:42:22  AA0158    5
# 3 2021-06-01 15:42:22  AA0110    6
# 4 2021-06-01 15:42:22  AA0108    7
#
#         qty
# sku_id
# AA0008    7
# AA0010    7
# AA0016    7
# AA0024    6
# AA0039    6
#
#    sku_id worker  avg_time  qty
# 0  AA0001   W001        41  NaN
# 1  AA0001   W002        35  NaN
# 2  AA0001   W003        35  NaN
# 3  AA0001   W004        33  NaN
# 4  AA0001   W005        39  NaN

# %%
# 8, this is tested script to run workers' assignment optimisation

from ortools.sat.python import cp_model
import csv
import datetime
from datetime import timedelta
import pandas as pd


w = [('1', datetime.datetime(2021, 6, 1, hour=8)), 
    ('2', datetime.datetime(2021, 6, 2, hour=8)),
    ('3', datetime.datetime(2021, 6, 3, hour=8)),
    ('4', datetime.datetime(2021, 6, 4, hour=8)),
    ('5', datetime.datetime(2021, 6, 7, hour=8)),
    ('6', datetime.datetime(2021, 6, 8, hour=8)),
    ('7', datetime.datetime(2021, 6, 9, hour=8)),
    ('8', datetime.datetime(2021, 6, 10, hour=8)),
    ('9', datetime.datetime(2021, 6, 11, hour=8)),
    ('10', datetime.datetime(2021, 6, 14, hour=8)),
    ('11', datetime.datetime(2021, 6, 15, hour=8)),
    ('12', datetime.datetime(2021, 6, 16, hour=8)),
    ('13', datetime.datetime(2021, 6, 17, hour=8)),
    ('14', datetime.datetime(2021, 6, 18, hour=8)),
    ('15', datetime.datetime(2021, 6, 21, hour=8)),
    ('16', datetime.datetime(2021, 6, 22, hour=8)),
    ('17', datetime.datetime(2021, 6, 23, hour=8)),
    ('18', datetime.datetime(2021, 6, 24, hour=8)),
    ('19', datetime.datetime(2021, 6, 25, hour=8)),
    ('20', datetime.datetime(2021, 6, 28, hour=8)),
    ('21', datetime.datetime(2021, 6, 29, hour=8)),
    ('22', datetime.datetime(2021, 6, 30, hour=8)),
    ]


# with open('task_worker_mins.csv', newline='') as f:
#     data = [list(map(int,rec)) for rec in csv.reader(f)]

#workers_pdty = pd.read_csv("dropzone_workers_productivity1.csv", index_col=False)


def main():
    for u, v in w:
        workers_pdty= pd.read_sql('SELECT * from processed_workers_productivity'+u, con = engine)
        workers_pdty1 = workers_pdty.dropna(how='all', axis=1).astype(int)
        skujoblist = list(workers_pdty1.columns.values)  # list of sku to be picked in this batch

        data = workers_pdty1.values.tolist()

        # Assign
        team_size = []
        assign_worker = []
        assign_task = []
        skujob = []
        assign_time = []
        start_time = v

        # Data
        costs = data
        num_workers = len(costs)
        total_tasks = len(costs[0])
        k = 0

        assign_timestamp_start = [start_time] * num_workers
        assign_timestamp_end = [start_time] * num_workers

        while total_tasks > num_workers:
            num_tasks = num_workers

            # Model
            model = cp_model.CpModel()

            # Variables
            x = []
            for i in range(num_workers):
                t = []
                for j in range(num_tasks):
                    t.append(model.NewBoolVar(f'x[{i},{j}]'))
                x.append(t)

            # Constraints
            # Each worker is assigned to at most one task.
            for i in range(num_workers):
                model.Add(sum(x[i][j] for j in range(num_tasks)) <= 1)

            # Each task is assigned to exactly one worker.
            for j in range(num_tasks):
                model.Add(sum(x[i][j] for i in range(num_workers)) == 1)

            # Objective
            objective_terms = []
            for i in range(num_workers):
                for j in range(num_tasks):
                    objective_terms.append(costs[i][j+k] * x[i][j])
            model.Minimize(sum(objective_terms))

            # Solve
            solver = cp_model.CpSolver()
            status = solver.Solve(model)

            # Print solution.
            if status == cp_model.OPTIMAL or status == cp_model.FEASIBLE:
                print(f'Total cost = {solver.ObjectiveValue()}')
                print()
                for i in range(num_workers):
                    start_time = assign_timestamp_end[k+i]
                    for j in range(num_tasks):
                        if solver.BooleanValue(x[i][j]):
                            end_time = start_time + timedelta(minutes=costs[i][j+k])
                            team_size.append(num_worker)
                            assign_worker.append('W'+str(i+1).zfill(3))
                            assign_task.append(j+k)
                            skujob.append(skujoblist[j+k])
                            assign_time.append(costs[i][j+k])
                            assign_timestamp_start.append(start_time)
                            assign_timestamp_end.append(end_time)
                            print(
                                f'Worker {i+1} assigned to task {j+k} sku {skujoblist[j+k]} Cost = {costs[i][j+k]} \
                                    start time = {start_time.strftime("%c")} , end time = {end_time.strftime("%c")}')
        
            else:
                print('No solution found.')

            total_tasks = total_tasks - num_tasks
            k = k + num_tasks
            print('total tasks completed = ', k, 'remaining task = ', total_tasks, '\n')

        else:
            num_tasks = total_tasks

            # Model
            model = cp_model.CpModel()

            # Variables
            x = []
            for i in range(num_workers):
                t = []
                for j in range(num_tasks):
                    t.append(model.NewBoolVar(f'x[{i},{j}]'))
                x.append(t)

            # Constraints
            # Each worker is assigned to at most one task.
            for i in range(num_workers):
                model.Add(sum(x[i][j] for j in range(num_tasks)) <= 1)

            # Each task is assigned to exactly one worker.
            for j in range(num_tasks):
                model.Add(sum(x[i][j] for i in range(num_workers)) == 1)

            # Objective
            objective_terms = []
            for i in range(num_workers):
                for j in range(num_tasks):
                    objective_terms.append(costs[i][j+k] * x[i][j])
            model.Minimize(sum(objective_terms))

            # Solve
            solver = cp_model.CpSolver()
            status = solver.Solve(model)

            # Print solution.
            if status == cp_model.OPTIMAL or status == cp_model.FEASIBLE:
                print(f'Total cost = {solver.ObjectiveValue()}')
                print()
                for i in range(num_workers):
                    start_time = assign_timestamp_end[k+i]
                    for j in range(num_tasks):
                        if solver.BooleanValue(x[i][j]):
                            end_time = start_time + timedelta(minutes=costs[i][j+k])
                            team_size.append(num_worker)
                            assign_worker.append('W'+str(i+1).zfill(3))
                            assign_task.append(j+k)
                            skujob.append(skujoblist[j+k])
                            assign_time.append(costs[i][j+k])
                            assign_timestamp_start.append(start_time)
                            assign_timestamp_end.append(end_time)
                            print(
                                f'Worker {i+1} assigned to task {j+k} sku {skujoblist[j+k]} Cost = {costs[i][j+k]} \
                                    start time = {start_time.strftime("%c")} end time = {end_time.strftime("%c")}')

            else:
                print('No solution found.')

            total_tasks = total_tasks - num_tasks
            k = k + num_tasks
            print('total tasks completed = ', k, 'remaining task = ', total_tasks, '\n')

        assign_timestamp_start = [i for i in assign_timestamp_start [num_workers:]]
        assign_timestamp_end = [i for i in assign_timestamp_end [num_workers:]]
        res = list(zip(team_size, assign_worker, assign_task, skujob, assign_time, assign_timestamp_start, assign_timestamp_end))
        # print(res)

        # with open('task_result2.csv', 'w') as f:
        #     writer = csv.writer(f, delimiter=',', lineterminator='\n')
        #     writer.writerows(res)

        res_df = pd.DataFrame(res, columns=['team_size', 'assign_worker', 'assign_task', 'skujob', 'assign_time', \
            'assign_timestamp_start', 'assign_timestamp_end'])
        # print(res_df)
        res_df.to_sql("job_assignment_result", engine, if_exists="append", index=False)

if __name__ == '__main__':
    main()
# Out:
# Total cost = 477.0
#
# Worker 1 assigned to task 2 sku AA0016 Cost = 38                                     start time = Tue Jun  1 08:00:00 2021 , end time = Tue Jun  1 08:38:00 2021
# Worker 2 assigned to task 7 sku AA0063 Cost = 40                                     start time = Tue Jun  1 08:00:00 2021 , end time = Tue Jun  1 08:40:00 2021
# Worker 3 assigned to task 0 sku AA0008 Cost = 43                                     start time = Tue Jun  1 08:00:00 2021 , end time = Tue Jun  1 08:43:00 2021
# Worker 4 assigned to task 8 sku AA0067 Cost = 39                                     start time = Tue Jun  1 08:00:00 2021 , end time = Tue Jun  1 08:39:00 2021
# Worker 5 assigned to task 10 sku AA0075 Cost = 33                                     start time = Tue Jun  1 08:00:00 2021 , end time = Tue Jun  1 08:33:00 2021
# Worker 6 assigned to task 4 sku AA0039 Cost = 38                                     start time = Tue Jun  1 08:00:00 2021 , end time = Tue Jun  1 08:38:00 2021
# Worker 7 assigned to task 3 sku AA0024 Cost = 40                                     start time = Tue Jun  1 08:00:00 2021 , end time = Tue Jun  1 08:40:00 2021
# Worker 8 assigned to task 11 sku AA0076 Cost = 53                                     start time = Tue Jun  1 08:00:00 2021 , end time = Tue Jun  1 08:53:00 2021
# Worker 9 assigned to task 5 sku AA0051 Cost = 38                                     start time = Tue Jun  1 08:00:00 2021 , end time = Tue Jun  1 08:38:00 2021
# Worker 10 assigned to task 1 sku AA0010 Cost = 40                                     start time = Tue Jun  1 08:00:00 2021 , end time = Tue Jun  1 08:40:00 2021
# Worker 11 assigned to task 6 sku AA0057 Cost = 41                                     start time = Tue Jun  1 08:00:00 2021 , end time = Tue Jun  1 08:41:00 2021
# Worker 12 assigned to task 9 sku AA0072 Cost = 34                                     start time = Tue Jun  1 08:00:00 2021 , end time = Tue Jun  1 08:34:00 2021
# total tasks completed =  12 remaining task =  34
#
# Total cost = 466.0
#
# Worker 1 assigned to task 23 sku AA0114 Cost = 39                                     start time = Tue Jun  1 08:38:00 2021 , end time = Tue Jun  1 09:17:00 2021
# Worker 2 assigned to task 13 sku AA0086 Cost = 39                                     start time = Tue Jun  1 08:40:00 2021 , end time = Tue Jun  1 09:19:00 2021
# Worker 3 assigned to task 18 sku AA0103 Cost = 42                                     start time = Tue Jun  1 08:43:00 2021 , end time = Tue Jun  1 09:25:00 2021
# Worker 4 assigned to task 21 sku AA0109 Cost = 43                                     start time = Tue Jun  1 08:39:00 2021 , end time = Tue Jun  1 09:22:00 2021
# Worker 5 assigned to task 17 sku AA0099 Cost = 40                                     start time = Tue Jun  1 08:33:00 2021 , end time = Tue Jun  1 09:13:00 2021
# Worker 6 assigned to task 12 sku AA0084 Cost = 34                                     start time = Tue Jun  1 08:38:00 2021 , end time = Tue Jun  1 09:12:00 2021
# Worker 7 assigned to task 15 sku AA0089 Cost = 40                                     start time = Tue Jun  1 08:40:00 2021 , end time = Tue Jun  1 09:20:00 2021
# Worker 8 assigned to task 19 sku AA0105 Cost = 37                                     start time = Tue Jun  1 08:53:00 2021 , end time = Tue Jun  1 09:30:00 2021
# Worker 9 assigned to task 14 sku AA0087 Cost = 34                                     start time = Tue Jun  1 08:38:00 2021 , end time = Tue Jun  1 09:12:00 2021
# Worker 10 assigned to task 16 sku AA0091 Cost = 37                                     start time = Tue Jun  1 08:40:00 2021 , end time = Tue Jun  1 09:17:00 2021
# Worker 11 assigned to task 22 sku AA0112 Cost = 42                                     start time = Tue Jun  1 08:41:00 2021 , end time = Tue Jun  1 09:23:00 2021
# Worker 12 assigned to task 20 sku AA0107 Cost = 39                                     start time = Tue Jun  1 08:34:00 2021 , end time = Tue Jun  1 09:13:00 2021
# total tasks completed =  24 remaining task =  22
#
# Total cost = 446.0
#
# Worker 1 assigned to task 30 sku AA0133 Cost = 39                                     start time = Tue Jun  1 09:17:00 2021 , end time = Tue Jun  1 09:56:00 2021
# Worker 2 assigned to task 25 sku AA0117 Cost = 33                                     start time = Tue Jun  1 09:19:00 2021 , end time = Tue Jun  1 09:52:00 2021
# Worker 3 assigned to task 24 sku AA0116 Cost = 35                                     start time = Tue Jun  1 09:25:00 2021 , end time = Tue Jun  1 10:00:00 2021
# Worker 4 assigned to task 32 sku AA0144 Cost = 40                                     start time = Tue Jun  1 09:22:00 2021 , end time = Tue Jun  1 10:02:00 2021
# Worker 5 assigned to task 31 sku AA0142 Cost = 37                                     start time = Tue Jun  1 09:13:00 2021 , end time = Tue Jun  1 09:50:00 2021
# Worker 6 assigned to task 34 sku AA0146 Cost = 36                                     start time = Tue Jun  1 09:12:00 2021 , end time = Tue Jun  1 09:48:00 2021
# Worker 7 assigned to task 35 sku AA0150 Cost = 39                                     start time = Tue Jun  1 09:20:00 2021 , end time = Tue Jun  1 09:59:00 2021
# Worker 8 assigned to task 26 sku AA0119 Cost = 42                                     start time = Tue Jun  1 09:30:00 2021 , end time = Tue Jun  1 10:12:00 2021
# Worker 9 assigned to task 33 sku AA0145 Cost = 38                                     start time = Tue Jun  1 09:12:00 2021 , end time = Tue Jun  1 09:50:00 2021
# Worker 10 assigned to task 28 sku AA0129 Cost = 38                                     start time = Tue Jun  1 09:17:00 2021 , end time = Tue Jun  1 09:55:00 2021
# Worker 11 assigned to task 29 sku AA0131 Cost = 38                                     start time = Tue Jun  1 09:23:00 2021 , end time = Tue Jun  1 10:01:00 2021
# Worker 12 assigned to task 27 sku AA0122 Cost = 31                                     start time = Tue Jun  1 09:13:00 2021 , end time = Tue Jun  1 09:44:00 2021
# total tasks completed =  36 remaining task =  10
#
# Total cost = 364.0
#
# Worker 1 assigned to task 38 sku AA0159 Cost = 39                                     start time = Tue Jun  1 09:56:00 2021 end time = Tue Jun  1 10:35:00 2021
# Worker 2 assigned to task 37 sku AA0155 Cost = 36                                     start time = Tue Jun  1 09:52:00 2021 end time = Tue Jun  1 10:28:00 2021
# Worker 4 assigned to task 36 sku AA0152 Cost = 39                                     start time = Tue Jun  1 10:02:00 2021 end time = Tue Jun  1 10:41:00 2021
# Worker 6 assigned to task 41 sku AA0179 Cost = 35                                     start time = Tue Jun  1 09:48:00 2021 end time = Tue Jun  1 10:23:00 2021
# Worker 7 assigned to task 42 sku AA0182 Cost = 36                                     start time = Tue Jun  1 09:59:00 2021 end time = Tue Jun  1 10:35:00 2021
# Worker 8 assigned to task 40 sku AA0176 Cost = 37                                     start time = Tue Jun  1 10:12:00 2021 end time = Tue Jun  1 10:49:00 2021
# Worker 9 assigned to task 45 sku AA0199 Cost = 37                                     start time = Tue Jun  1 09:50:00 2021 end time = Tue Jun  1 10:27:00 2021
# Worker 10 assigned to task 39 sku AA0165 Cost = 33                                     start time = Tue Jun  1 09:55:00 2021 end time = Tue Jun  1 10:28:00 2021
# Worker 11 assigned to task 44 sku AA0198 Cost = 35                                     start time = Tue Jun  1 10:01:00 2021 end time = Tue Jun  1 10:36:00 2021
# Worker 12 assigned to task 43 sku AA0185 Cost = 37                                     start time = Tue Jun  1 09:44:00 2021 end time = Tue Jun  1 10:21:00 2021
# total tasks completed =  46 remaining task =  0
#
# Total cost = 482.0
#
# Worker 1 assigned to task 11 sku AA0024 Cost = 36                                     start time = Wed Jun  2 08:00:00 2021 , end time = Wed Jun  2 08:36:00 2021
# Worker 2 assigned to task 6 sku AA0015 Cost = 41                                     start time = Wed Jun  2 08:00:00 2021 , end time = Wed Jun  2 08:41:00 2021
# Worker 3 assigned to task 1 sku AA0008 Cost = 48                                     start time = Wed Jun  2 08:00:00 2021 , end time = Wed Jun  2 08:48:00 2021
# Worker 4 assigned to task 8 sku AA0018 Cost = 44                                     start time = Wed Jun  2 08:00:00 2021 , end time = Wed Jun  2 08:44:00 2021
# Worker 5 assigned to task 3 sku AA0011 Cost = 36                                     start time = Wed Jun  2 08:00:00 2021 , end time = Wed Jun  2 08:36:00 2021
# Worker 6 assigned to task 4 sku AA0012 Cost = 41                                     start time = Wed Jun  2 08:00:00 2021 , end time = Wed Jun  2 08:41:00 2021
# Worker 7 assigned to task 7 sku AA0016 Cost = 41                                     start time = Wed Jun  2 08:00:00 2021 , end time = Wed Jun  2 08:41:00 2021
# Worker 8 assigned to task 5 sku AA0013 Cost = 34                                     start time = Wed Jun  2 08:00:00 2021 , end time = Wed Jun  2 08:34:00 2021
# Worker 9 assigned to task 9 sku AA0019 Cost = 34                                     start time = Wed Jun  2 08:00:00 2021 , end time = Wed Jun  2 08:34:00 2021
# Worker 10 assigned to task 2 sku AA0010 Cost = 44                                     start time = Wed Jun  2 08:00:00 2021 , end time = Wed Jun  2 08:44:00 2021
# Worker 11 assigned to task 10 sku AA0020 Cost = 37                                     start time = Wed Jun  2 08:00:00 2021 , end time = Wed Jun  2 08:37:00 2021
# Worker 12 assigned to task 0 sku AA0006 Cost = 46                                     start time = Wed Jun  2 08:00:00 2021 , end time = Wed Jun  2 08:46:00 2021
# total tasks completed =  12 remaining task =  97
#
# Total cost = 471.0
#
# Worker 1 assigned to task 12 sku AA0025 Cost = 37                                     start time = Wed Jun  2 08:36:00 2021 , end time = Wed Jun  2 09:13:00 2021
# Worker 2 assigned to task 16 sku AA0030 Cost = 36                                     start time = Wed Jun  2 08:41:00 2021 , end time = Wed Jun  2 09:17:00 2021
# Worker 3 assigned to task 15 sku AA0029 Cost = 35                                     start time = Wed Jun  2 08:48:00 2021 , end time = Wed Jun  2 09:23:00 2021
# Worker 4 assigned to task 19 sku AA0036 Cost = 42                                     start time = Wed Jun  2 08:44:00 2021 , end time = Wed Jun  2 09:26:00 2021
# Worker 5 assigned to task 21 sku AA0039 Cost = 46                                     start time = Wed Jun  2 08:36:00 2021 , end time = Wed Jun  2 09:22:00 2021
# Worker 6 assigned to task 23 sku AA0042 Cost = 35                                     start time = Wed Jun  2 08:41:00 2021 , end time = Wed Jun  2 09:16:00 2021
# Worker 7 assigned to task 17 sku AA0032 Cost = 36                                     start time = Wed Jun  2 08:41:00 2021 , end time = Wed Jun  2 09:17:00 2021
# Worker 8 assigned to task 13 sku AA0026 Cost = 39                                     start time = Wed Jun  2 08:34:00 2021 , end time = Wed Jun  2 09:13:00 2021
# Worker 9 assigned to task 14 sku AA0028 Cost = 46                                     start time = Wed Jun  2 08:34:00 2021 , end time = Wed Jun  2 09:20:00 2021
# Worker 10 assigned to task 22 sku AA0041 Cost = 41                                     start time = Wed Jun  2 08:44:00 2021 , end time = Wed Jun  2 09:25:00 2021
# Worker 11 assigned to task 18 sku AA0033 Cost = 38                                     start time = Wed Jun  2 08:37:00 2021 , end time = Wed Jun  2 09:15:00 2021
# Worker 12 assigned to task 20 sku AA0038 Cost = 40                                     start time = Wed Jun  2 08:46:00 2021 , end time = Wed Jun  2 09:26:00 2021
# total tasks completed =  24 remaining task =  85
#
# Total cost = 510.0
#
# Worker 1 assigned to task 29 sku AA0051 Cost = 44                                     start time = Wed Jun  2 09:13:00 2021 , end time = Wed Jun  2 09:57:00 2021
# Worker 2 assigned to task 28 sku AA0050 Cost = 36                                     start time = Wed Jun  2 09:17:00 2021 , end time = Wed Jun  2 09:53:00 2021
# Worker 3 assigned to task 33 sku AA0057 Cost = 42                                     start time = Wed Jun  2 09:23:00 2021 , end time = Wed Jun  2 10:05:00 2021
# Worker 4 assigned to task 35 sku AA0059 Cost = 54                                     start time = Wed Jun  2 09:26:00 2021 , end time = Wed Jun  2 10:20:00 2021
# Worker 5 assigned to task 25 sku AA0046 Cost = 47                                     start time = Wed Jun  2 09:22:00 2021 , end time = Wed Jun  2 10:09:00 2021
# Worker 6 assigned to task 30 sku AA0053 Cost = 38                                     start time = Wed Jun  2 09:16:00 2021 , end time = Wed Jun  2 09:54:00 2021
# Worker 7 assigned to task 26 sku AA0047 Cost = 51                                     start time = Wed Jun  2 09:17:00 2021 , end time = Wed Jun  2 10:08:00 2021
# Worker 8 assigned to task 34 sku AA0058 Cost = 43                                     start time = Wed Jun  2 09:13:00 2021 , end time = Wed Jun  2 09:56:00 2021
# Worker 9 assigned to task 32 sku AA0056 Cost = 43                                     start time = Wed Jun  2 09:20:00 2021 , end time = Wed Jun  2 10:03:00 2021
# Worker 10 assigned to task 24 sku AA0043 Cost = 37                                     start time = Wed Jun  2 09:25:00 2021 , end time = Wed Jun  2 10:02:00 2021
# Worker 11 assigned to task 31 sku AA0054 Cost = 38                                     start time = Wed Jun  2 09:15:00 2021 , end time = Wed Jun  2 09:53:00 2021
# Worker 12 assigned to task 27 sku AA0049 Cost = 37                                     start time = Wed Jun  2 09:26:00 2021 , end time = Wed Jun  2 10:03:00 2021
# total tasks completed =  36 remaining task =  73
#
# Total cost = 472.0
#
# Worker 1 assigned to task 37 sku AA0065 Cost = 33                                     start time = Wed Jun  2 09:57:00 2021 , end time = Wed Jun  2 10:30:00 2021
# Worker 2 assigned to task 44 sku AA0080 Cost = 45                                     start time = Wed Jun  2 09:53:00 2021 , end time = Wed Jun  2 10:38:00 2021
# Worker 3 assigned to task 38 sku AA0069 Cost = 55                                     start time = Wed Jun  2 10:05:00 2021 , end time = Wed Jun  2 11:00:00 2021
# Worker 4 assigned to task 45 sku AA0081 Cost = 35                                     start time = Wed Jun  2 10:20:00 2021 , end time = Wed Jun  2 10:55:00 2021
# Worker 5 assigned to task 41 sku AA0075 Cost = 32                                     start time = Wed Jun  2 10:09:00 2021 , end time = Wed Jun  2 10:41:00 2021
# Worker 6 assigned to task 46 sku AA0083 Cost = 38                                     start time = Wed Jun  2 09:54:00 2021 , end time = Wed Jun  2 10:32:00 2021
# Worker 7 assigned to task 39 sku AA0071 Cost = 46                                     start time = Wed Jun  2 10:08:00 2021 , end time = Wed Jun  2 10:54:00 2021
# Worker 8 assigned to task 40 sku AA0073 Cost = 41                                     start time = Wed Jun  2 09:56:00 2021 , end time = Wed Jun  2 10:37:00 2021
# Worker 9 assigned to task 47 sku AA0088 Cost = 39                                     start time = Wed Jun  2 10:03:00 2021 , end time = Wed Jun  2 10:42:00 2021
# Worker 10 assigned to task 36 sku AA0064 Cost = 33                                     start time = Wed Jun  2 10:02:00 2021 , end time = Wed Jun  2 10:35:00 2021
# Worker 11 assigned to task 43 sku AA0079 Cost = 41                                     start time = Wed Jun  2 09:53:00 2021 , end time = Wed Jun  2 10:34:00 2021
# Worker 12 assigned to task 42 sku AA0078 Cost = 34                                     start time = Wed Jun  2 10:03:00 2021 , end time = Wed Jun  2 10:37:00 2021
# total tasks completed =  48 remaining task =  61
#
# Total cost = 484.0
#
# Worker 1 assigned to task 58 sku AA0108 Cost = 43                                     start time = Wed Jun  2 10:30:00 2021 , end time = Wed Jun  2 11:13:00 2021
# Worker 2 assigned to task 56 sku AA0105 Cost = 38                                     start time = Wed Jun  2 10:38:00 2021 , end time = Wed Jun  2 11:16:00 2021
# Worker 3 assigned to task 55 sku AA0103 Cost = 47                                     start time = Wed Jun  2 11:00:00 2021 , end time = Wed Jun  2 11:47:00 2021
# Worker 4 assigned to task 59 sku AA0109 Cost = 39                                     start time = Wed Jun  2 10:55:00 2021 , end time = Wed Jun  2 11:34:00 2021
# Worker 5 assigned to task 52 sku AA0098 Cost = 30                                     start time = Wed Jun  2 10:41:00 2021 , end time = Wed Jun  2 11:11:00 2021
# Worker 6 assigned to task 53 sku AA0100 Cost = 40                                     start time = Wed Jun  2 10:32:00 2021 , end time = Wed Jun  2 11:12:00 2021
# Worker 7 assigned to task 49 sku AA0094 Cost = 40                                     start time = Wed Jun  2 10:54:00 2021 , end time = Wed Jun  2 11:34:00 2021
# Worker 8 assigned to task 54 sku AA0101 Cost = 46                                     start time = Wed Jun  2 10:37:00 2021 , end time = Wed Jun  2 11:23:00 2021
# Worker 9 assigned to task 50 sku AA0096 Cost = 41                                     start time = Wed Jun  2 10:42:00 2021 , end time = Wed Jun  2 11:23:00 2021
# Worker 10 assigned to task 48 sku AA0091 Cost = 43                                     start time = Wed Jun  2 10:35:00 2021 , end time = Wed Jun  2 11:18:00 2021
# Worker 11 assigned to task 51 sku AA0097 Cost = 37                                     start time = Wed Jun  2 10:34:00 2021 , end time = Wed Jun  2 11:11:00 2021
# Worker 12 assigned to task 57 sku AA0107 Cost = 40                                     start time = Wed Jun  2 10:37:00 2021 , end time = Wed Jun  2 11:17:00 2021
# total tasks completed =  60 remaining task =  49
#
# Total cost = 430.0
#
# Worker 1 assigned to task 60 sku AA0110 Cost = 41                                     start time = Wed Jun  2 11:13:00 2021 , end time = Wed Jun  2 11:54:00 2021
# Worker 2 assigned to task 70 sku AA0125 Cost = 28                                     start time = Wed Jun  2 11:16:00 2021 , end time = Wed Jun  2 11:44:00 2021
# Worker 3 assigned to task 64 sku AA0116 Cost = 33                                     start time = Wed Jun  2 11:47:00 2021 , end time = Wed Jun  2 12:20:00 2021
# Worker 4 assigned to task 69 sku AA0124 Cost = 39                                     start time = Wed Jun  2 11:34:00 2021 , end time = Wed Jun  2 12:13:00 2021
# Worker 5 assigned to task 63 sku AA0114 Cost = 43                                     start time = Wed Jun  2 11:11:00 2021 , end time = Wed Jun  2 11:54:00 2021
# Worker 6 assigned to task 68 sku AA0123 Cost = 36                                     start time = Wed Jun  2 11:12:00 2021 , end time = Wed Jun  2 11:48:00 2021
# Worker 7 assigned to task 66 sku AA0120 Cost = 36                                     start time = Wed Jun  2 11:34:00 2021 , end time = Wed Jun  2 12:10:00 2021
# Worker 8 assigned to task 71 sku AA0126 Cost = 36                                     start time = Wed Jun  2 11:23:00 2021 , end time = Wed Jun  2 11:59:00 2021
# Worker 9 assigned to task 62 sku AA0113 Cost = 31                                     start time = Wed Jun  2 11:23:00 2021 , end time = Wed Jun  2 11:54:00 2021
# Worker 10 assigned to task 61 sku AA0111 Cost = 42                                     start time = Wed Jun  2 11:18:00 2021 , end time = Wed Jun  2 12:00:00 2021
# Worker 11 assigned to task 65 sku AA0118 Cost = 35                                     start time = Wed Jun  2 11:11:00 2021 , end time = Wed Jun  2 11:46:00 2021
# Worker 12 assigned to task 67 sku AA0122 Cost = 30                                     start time = Wed Jun  2 11:17:00 2021 , end time = Wed Jun  2 11:47:00 2021
# total tasks completed =  72 remaining task =  37
#
# Total cost = 456.0
#
# Worker 1 assigned to task 79 sku AA0139 Cost = 40                                     start time = Wed Jun  2 11:54:00 2021 , end time = Wed Jun  2 12:34:00 2021
# Worker 2 assigned to task 75 sku AA0130 Cost = 36                                     start time = Wed Jun  2 11:44:00 2021 , end time = Wed Jun  2 12:20:00 2021
# Worker 3 assigned to task 81 sku AA0149 Cost = 39                                     start time = Wed Jun  2 12:20:00 2021 , end time = Wed Jun  2 12:59:00 2021
# Worker 4 assigned to task 83 sku AA0152 Cost = 37                                     start time = Wed Jun  2 12:13:00 2021 , end time = Wed Jun  2 12:50:00 2021
# Worker 5 assigned to task 72 sku AA0127 Cost = 32                                     start time = Wed Jun  2 11:54:00 2021 , end time = Wed Jun  2 12:26:00 2021
# Worker 6 assigned to task 74 sku AA0129 Cost = 46                                     start time = Wed Jun  2 11:48:00 2021 , end time = Wed Jun  2 12:34:00 2021
# Worker 7 assigned to task 82 sku AA0150 Cost = 37                                     start time = Wed Jun  2 12:10:00 2021 , end time = Wed Jun  2 12:47:00 2021
# Worker 8 assigned to task 73 sku AA0128 Cost = 35                                     start time = Wed Jun  2 11:59:00 2021 , end time = Wed Jun  2 12:34:00 2021
# Worker 9 assigned to task 78 sku AA0138 Cost = 42                                     start time = Wed Jun  2 11:54:00 2021 , end time = Wed Jun  2 12:36:00 2021
# Worker 10 assigned to task 76 sku AA0132 Cost = 38                                     start time = Wed Jun  2 12:00:00 2021 , end time = Wed Jun  2 12:38:00 2021
# Worker 11 assigned to task 77 sku AA0137 Cost = 40                                     start time = Wed Jun  2 11:46:00 2021 , end time = Wed Jun  2 12:26:00 2021
# Worker 12 assigned to task 80 sku AA0146 Cost = 34                                     start time = Wed Jun  2 11:47:00 2021 , end time = Wed Jun  2 12:21:00 2021
# total tasks completed =  84 remaining task =  25
#
# Total cost = 464.0
#
# Worker 1 assigned to task 92 sku AA0168 Cost = 33                                     start time = Wed Jun  2 12:34:00 2021 , end time = Wed Jun  2 13:07:00 2021
# Worker 2 assigned to task 85 sku AA0154 Cost = 47                                     start time = Wed Jun  2 12:20:00 2021 , end time = Wed Jun  2 13:07:00 2021
# Worker 3 assigned to task 94 sku AA0173 Cost = 37                                     start time = Wed Jun  2 12:59:00 2021 , end time = Wed Jun  2 13:36:00 2021
# Worker 4 assigned to task 91 sku AA0167 Cost = 43                                     start time = Wed Jun  2 12:50:00 2021 , end time = Wed Jun  2 13:33:00 2021
# Worker 5 assigned to task 87 sku AA0157 Cost = 48                                     start time = Wed Jun  2 12:26:00 2021 , end time = Wed Jun  2 13:14:00 2021
# Worker 6 assigned to task 86 sku AA0156 Cost = 34                                     start time = Wed Jun  2 12:34:00 2021 , end time = Wed Jun  2 13:08:00 2021
# Worker 7 assigned to task 90 sku AA0164 Cost = 32                                     start time = Wed Jun  2 12:47:00 2021 , end time = Wed Jun  2 13:19:00 2021
# Worker 8 assigned to task 95 sku AA0174 Cost = 39                                     start time = Wed Jun  2 12:34:00 2021 , end time = Wed Jun  2 13:13:00 2021
# Worker 9 assigned to task 93 sku AA0172 Cost = 36                                     start time = Wed Jun  2 12:36:00 2021 , end time = Wed Jun  2 13:12:00 2021
# Worker 10 assigned to task 84 sku AA0153 Cost = 41                                     start time = Wed Jun  2 12:38:00 2021 , end time = Wed Jun  2 13:19:00 2021
# Worker 11 assigned to task 88 sku AA0158 Cost = 35                                     start time = Wed Jun  2 12:26:00 2021 , end time = Wed Jun  2 13:01:00 2021
# Worker 12 assigned to task 89 sku AA0159 Cost = 39                                     start time = Wed Jun  2 12:21:00 2021 , end time = Wed Jun  2 13:00:00 2021
# total tasks completed =  96 remaining task =  13
#
# Total cost = 463.0
#
# Worker 1 assigned to task 105 sku AA0195 Cost = 51                                     start time = Wed Jun  2 13:07:00 2021 , end time = Wed Jun  2 13:58:00 2021
# Worker 2 assigned to task 102 sku AA0187 Cost = 38                                     start time = Wed Jun  2 13:07:00 2021 , end time = Wed Jun  2 13:45:00 2021
# Worker 3 assigned to task 106 sku AA0197 Cost = 29                                     start time = Wed Jun  2 13:36:00 2021 , end time = Wed Jun  2 14:05:00 2021
# Worker 4 assigned to task 100 sku AA0184 Cost = 40                                     start time = Wed Jun  2 13:33:00 2021 , end time = Wed Jun  2 14:13:00 2021
# Worker 5 assigned to task 96 sku AA0180 Cost = 35                                     start time = Wed Jun  2 13:14:00 2021 , end time = Wed Jun  2 13:49:00 2021
# Worker 6 assigned to task 99 sku AA0183 Cost = 41                                     start time = Wed Jun  2 13:08:00 2021 , end time = Wed Jun  2 13:49:00 2021
# Worker 7 assigned to task 103 sku AA0191 Cost = 37                                     start time = Wed Jun  2 13:19:00 2021 , end time = Wed Jun  2 13:56:00 2021
# Worker 8 assigned to task 97 sku AA0181 Cost = 39                                     start time = Wed Jun  2 13:13:00 2021 , end time = Wed Jun  2 13:52:00 2021
# Worker 9 assigned to task 104 sku AA0192 Cost = 41                                     start time = Wed Jun  2 13:12:00 2021 , end time = Wed Jun  2 13:53:00 2021
# Worker 10 assigned to task 98 sku AA0182 Cost = 37                                     start time = Wed Jun  2 13:19:00 2021 , end time = Wed Jun  2 13:56:00 2021
# Worker 11 assigned to task 107 sku AA0198 Cost = 37                                     start time = Wed Jun  2 13:01:00 2021 , end time = Wed Jun  2 13:38:00 2021
# Worker 12 assigned to task 101 sku AA0185 Cost = 38                                     start time = Wed Jun  2 13:00:00 2021 , end time = Wed Jun  2 13:38:00 2021
# total tasks completed =  108 remaining task =  1
#
# Total cost = 38.0
#
# Worker 9 assigned to task 108 sku AA0199 Cost = 38                                     start time = Wed Jun  2 13:53:00 2021 end time = Wed Jun  2 14:31:00 2021
# total tasks completed =  109 remaining task =  0
#
# Total cost = 476.0
#
# Worker 1 assigned to task 7 sku AA0016 Cost = 37                                     start time = Thu Jun  3 08:00:00 2021 , end time = Thu Jun  3 08:37:00 2021
# Worker 2 assigned to task 11 sku AA0030 Cost = 43                                     start time = Thu Jun  3 08:00:00 2021 , end time = Thu Jun  3 08:43:00 2021
# Worker 3 assigned to task 3 sku AA0008 Cost = 41                                     start time = Thu Jun  3 08:00:00 2021 , end time = Thu Jun  3 08:41:00 2021
# Worker 4 assigned to task 8 sku AA0017 Cost = 39                                     start time = Thu Jun  3 08:00:00 2021 , end time = Thu Jun  3 08:39:00 2021
# Worker 5 assigned to task 4 sku AA0011 Cost = 40                                     start time = Thu Jun  3 08:00:00 2021 , end time = Thu Jun  3 08:40:00 2021
# Worker 6 assigned to task 5 sku AA0012 Cost = 40                                     start time = Thu Jun  3 08:00:00 2021 , end time = Thu Jun  3 08:40:00 2021
# Worker 7 assigned to task 2 sku AA0003 Cost = 36                                     start time = Thu Jun  3 08:00:00 2021 , end time = Thu Jun  3 08:36:00 2021
# Worker 8 assigned to task 6 sku AA0013 Cost = 34                                     start time = Thu Jun  3 08:00:00 2021 , end time = Thu Jun  3 08:34:00 2021
# Worker 9 assigned to task 1 sku AA0002 Cost = 45                                     start time = Thu Jun  3 08:00:00 2021 , end time = Thu Jun  3 08:45:00 2021
# Worker 10 assigned to task 9 sku AA0021 Cost = 37                                     start time = Thu Jun  3 08:00:00 2021 , end time = Thu Jun  3 08:37:00 2021
# Worker 11 assigned to task 10 sku AA0023 Cost = 47                                     start time = Thu Jun  3 08:00:00 2021 , end time = Thu Jun  3 08:47:00 2021
# Worker 12 assigned to task 0 sku AA0001 Cost = 37                                     start time = Thu Jun  3 08:00:00 2021 , end time = Thu Jun  3 08:37:00 2021
# total tasks completed =  12 remaining task =  67
#
# Total cost = 475.0
#
# Worker 1 assigned to task 18 sku AA0044 Cost = 43                                     start time = Thu Jun  3 08:37:00 2021 , end time = Thu Jun  3 09:20:00 2021
# Worker 2 assigned to task 19 sku AA0047 Cost = 49                                     start time = Thu Jun  3 08:43:00 2021 , end time = Thu Jun  3 09:32:00 2021
# Worker 3 assigned to task 17 sku AA0043 Cost = 40                                     start time = Thu Jun  3 08:41:00 2021 , end time = Thu Jun  3 09:21:00 2021
# Worker 4 assigned to task 23 sku AA0059 Cost = 41                                     start time = Thu Jun  3 08:39:00 2021 , end time = Thu Jun  3 09:20:00 2021
# Worker 5 assigned to task 20 sku AA0048 Cost = 41                                     start time = Thu Jun  3 08:40:00 2021 , end time = Thu Jun  3 09:21:00 2021
# Worker 6 assigned to task 21 sku AA0049 Cost = 45                                     start time = Thu Jun  3 08:40:00 2021 , end time = Thu Jun  3 09:25:00 2021
# Worker 7 assigned to task 22 sku AA0058 Cost = 40                                     start time = Thu Jun  3 08:36:00 2021 , end time = Thu Jun  3 09:16:00 2021
# Worker 8 assigned to task 12 sku AA0031 Cost = 32                                     start time = Thu Jun  3 08:34:00 2021 , end time = Thu Jun  3 09:06:00 2021
# Worker 9 assigned to task 16 sku AA0040 Cost = 35                                     start time = Thu Jun  3 08:45:00 2021 , end time = Thu Jun  3 09:20:00 2021
# Worker 10 assigned to task 15 sku AA0037 Cost = 35                                     start time = Thu Jun  3 08:37:00 2021 , end time = Thu Jun  3 09:12:00 2021
# Worker 11 assigned to task 13 sku AA0033 Cost = 39                                     start time = Thu Jun  3 08:47:00 2021 , end time = Thu Jun  3 09:26:00 2021
# Worker 12 assigned to task 14 sku AA0035 Cost = 35                                     start time = Thu Jun  3 08:37:00 2021 , end time = Thu Jun  3 09:12:00 2021
# total tasks completed =  24 remaining task =  55
#
# Total cost = 469.0
#
# Worker 1 assigned to task 24 sku AA0061 Cost = 30                                     start time = Thu Jun  3 09:20:00 2021 , end time = Thu Jun  3 09:50:00 2021
# Worker 2 assigned to task 34 sku AA0082 Cost = 37                                     start time = Thu Jun  3 09:32:00 2021 , end time = Thu Jun  3 10:09:00 2021
# Worker 3 assigned to task 32 sku AA0080 Cost = 49                                     start time = Thu Jun  3 09:21:00 2021 , end time = Thu Jun  3 10:10:00 2021
# Worker 4 assigned to task 33 sku AA0081 Cost = 38                                     start time = Thu Jun  3 09:20:00 2021 , end time = Thu Jun  3 09:58:00 2021
# Worker 5 assigned to task 29 sku AA0075 Cost = 43                                     start time = Thu Jun  3 09:21:00 2021 , end time = Thu Jun  3 10:04:00 2021
# Worker 6 assigned to task 35 sku AA0084 Cost = 41                                     start time = Thu Jun  3 09:25:00 2021 , end time = Thu Jun  3 10:06:00 2021
# Worker 7 assigned to task 25 sku AA0062 Cost = 33                                     start time = Thu Jun  3 09:16:00 2021 , end time = Thu Jun  3 09:49:00 2021
# Worker 8 assigned to task 30 sku AA0077 Cost = 38                                     start time = Thu Jun  3 09:06:00 2021 , end time = Thu Jun  3 09:44:00 2021
# Worker 9 assigned to task 27 sku AA0069 Cost = 43                                     start time = Thu Jun  3 09:20:00 2021 , end time = Thu Jun  3 10:03:00 2021
# Worker 10 assigned to task 26 sku AA0064 Cost = 32                                     start time = Thu Jun  3 09:12:00 2021 , end time = Thu Jun  3 09:44:00 2021
# Worker 11 assigned to task 31 sku AA0079 Cost = 45                                     start time = Thu Jun  3 09:26:00 2021 , end time = Thu Jun  3 10:11:00 2021
# Worker 12 assigned to task 28 sku AA0072 Cost = 40                                     start time = Thu Jun  3 09:12:00 2021 , end time = Thu Jun  3 09:52:00 2021
# total tasks completed =  36 remaining task =  43
#
# Total cost = 453.0
#
# Worker 1 assigned to task 46 sku AA0110 Cost = 35                                     start time = Thu Jun  3 09:50:00 2021 , end time = Thu Jun  3 10:25:00 2021
# Worker 2 assigned to task 37 sku AA0088 Cost = 41                                     start time = Thu Jun  3 10:09:00 2021 , end time = Thu Jun  3 10:50:00 2021
# Worker 3 assigned to task 39 sku AA0090 Cost = 33                                     start time = Thu Jun  3 10:10:00 2021 , end time = Thu Jun  3 10:43:00 2021
# Worker 4 assigned to task 45 sku AA0109 Cost = 38                                     start time = Thu Jun  3 09:58:00 2021 , end time = Thu Jun  3 10:36:00 2021
# Worker 5 assigned to task 47 sku AA0116 Cost = 40                                     start time = Thu Jun  3 10:04:00 2021 , end time = Thu Jun  3 10:44:00 2021
# Worker 6 assigned to task 42 sku AA0102 Cost = 40                                     start time = Thu Jun  3 10:06:00 2021 , end time = Thu Jun  3 10:46:00 2021
# Worker 7 assigned to task 40 sku AA0094 Cost = 34                                     start time = Thu Jun  3 09:49:00 2021 , end time = Thu Jun  3 10:23:00 2021
# Worker 8 assigned to task 41 sku AA0101 Cost = 38                                     start time = Thu Jun  3 09:44:00 2021 , end time = Thu Jun  3 10:22:00 2021
# Worker 9 assigned to task 44 sku AA0108 Cost = 37                                     start time = Thu Jun  3 10:03:00 2021 , end time = Thu Jun  3 10:40:00 2021
# Worker 10 assigned to task 36 sku AA0086 Cost = 45                                     start time = Thu Jun  3 09:44:00 2021 , end time = Thu Jun  3 10:29:00 2021
# Worker 11 assigned to task 43 sku AA0106 Cost = 35                                     start time = Thu Jun  3 10:11:00 2021 , end time = Thu Jun  3 10:46:00 2021
# Worker 12 assigned to task 38 sku AA0089 Cost = 37                                     start time = Thu Jun  3 09:52:00 2021 , end time = Thu Jun  3 10:29:00 2021
# total tasks completed =  48 remaining task =  31
#
# Total cost = 454.0
#
# Worker 1 assigned to task 55 sku AA0133 Cost = 38                                     start time = Thu Jun  3 10:25:00 2021 , end time = Thu Jun  3 11:03:00 2021
# Worker 2 assigned to task 48 sku AA0117 Cost = 34                                     start time = Thu Jun  3 10:50:00 2021 , end time = Thu Jun  3 11:24:00 2021
# Worker 3 assigned to task 50 sku AA0120 Cost = 42                                     start time = Thu Jun  3 10:43:00 2021 , end time = Thu Jun  3 11:25:00 2021
# Worker 4 assigned to task 56 sku AA0136 Cost = 35                                     start time = Thu Jun  3 10:36:00 2021 , end time = Thu Jun  3 11:11:00 2021
# Worker 5 assigned to task 59 sku AA0143 Cost = 34                                     start time = Thu Jun  3 10:44:00 2021 , end time = Thu Jun  3 11:18:00 2021
# Worker 6 assigned to task 52 sku AA0123 Cost = 41                                     start time = Thu Jun  3 10:46:00 2021 , end time = Thu Jun  3 11:27:00 2021
# Worker 7 assigned to task 53 sku AA0131 Cost = 40                                     start time = Thu Jun  3 10:23:00 2021 , end time = Thu Jun  3 11:03:00 2021
# Worker 8 assigned to task 58 sku AA0138 Cost = 39                                     start time = Thu Jun  3 10:22:00 2021 , end time = Thu Jun  3 11:01:00 2021
# Worker 9 assigned to task 51 sku AA0121 Cost = 40                                     start time = Thu Jun  3 10:40:00 2021 , end time = Thu Jun  3 11:20:00 2021
# Worker 10 assigned to task 54 sku AA0132 Cost = 36                                     start time = Thu Jun  3 10:29:00 2021 , end time = Thu Jun  3 11:05:00 2021
# Worker 11 assigned to task 49 sku AA0118 Cost = 36                                     start time = Thu Jun  3 10:46:00 2021 , end time = Thu Jun  3 11:22:00 2021
# Worker 12 assigned to task 57 sku AA0137 Cost = 39                                     start time = Thu Jun  3 10:29:00 2021 , end time = Thu Jun  3 11:08:00 2021
# total tasks completed =  60 remaining task =  19
#
# Total cost = 445.0
#
# Worker 1 assigned to task 68 sku AA0167 Cost = 41                                     start time = Thu Jun  3 11:03:00 2021 , end time = Thu Jun  3 11:44:00 2021
# Worker 2 assigned to task 63 sku AA0155 Cost = 36                                     start time = Thu Jun  3 11:24:00 2021 , end time = Thu Jun  3 12:00:00 2021
# Worker 3 assigned to task 61 sku AA0146 Cost = 36                                     start time = Thu Jun  3 11:25:00 2021 , end time = Thu Jun  3 12:01:00 2021
# Worker 4 assigned to task 62 sku AA0151 Cost = 36                                     start time = Thu Jun  3 11:11:00 2021 , end time = Thu Jun  3 11:47:00 2021
# Worker 5 assigned to task 65 sku AA0157 Cost = 38                                     start time = Thu Jun  3 11:18:00 2021 , end time = Thu Jun  3 11:56:00 2021
# Worker 6 assigned to task 70 sku AA0179 Cost = 36                                     start time = Thu Jun  3 11:27:00 2021 , end time = Thu Jun  3 12:03:00 2021
# Worker 7 assigned to task 71 sku AA0183 Cost = 40                                     start time = Thu Jun  3 11:03:00 2021 , end time = Thu Jun  3 11:43:00 2021
# Worker 8 assigned to task 69 sku AA0176 Cost = 35                                     start time = Thu Jun  3 11:01:00 2021 , end time = Thu Jun  3 11:36:00 2021
# Worker 9 assigned to task 64 sku AA0156 Cost = 38                                     start time = Thu Jun  3 11:20:00 2021 , end time = Thu Jun  3 11:58:00 2021
# Worker 10 assigned to task 67 sku AA0165 Cost = 33                                     start time = Thu Jun  3 11:05:00 2021 , end time = Thu Jun  3 11:38:00 2021
# Worker 11 assigned to task 66 sku AA0162 Cost = 34                                     start time = Thu Jun  3 11:22:00 2021 , end time = Thu Jun  3 11:56:00 2021
# Worker 12 assigned to task 60 sku AA0145 Cost = 42                                     start time = Thu Jun  3 11:08:00 2021 , end time = Thu Jun  3 11:50:00 2021
# total tasks completed =  72 remaining task =  7
#
# Total cost = 252.0
#
# Worker 1 assigned to task 74 sku AA0190 Cost = 29                                     start time = Thu Jun  3 11:44:00 2021 end time = Thu Jun  3 12:13:00 2021
# Worker 2 assigned to task 73 sku AA0187 Cost = 36                                     start time = Thu Jun  3 12:00:00 2021 end time = Thu Jun  3 12:36:00 2021
# Worker 3 assigned to task 76 sku AA0195 Cost = 41                                     start time = Thu Jun  3 12:01:00 2021 end time = Thu Jun  3 12:42:00 2021
# Worker 9 assigned to task 75 sku AA0192 Cost = 38                                     start time = Thu Jun  3 11:58:00 2021 end time = Thu Jun  3 12:36:00 2021
# Worker 10 assigned to task 77 sku AA0196 Cost = 34                                     start time = Thu Jun  3 11:38:00 2021 end time = Thu Jun  3 12:12:00 2021
# Worker 11 assigned to task 78 sku AA0198 Cost = 36                                     start time = Thu Jun  3 11:56:00 2021 end time = Thu Jun  3 12:32:00 2021
# Worker 12 assigned to task 72 sku AA0185 Cost = 38                                     start time = Thu Jun  3 11:50:00 2021 end time = Thu Jun  3 12:28:00 2021
# total tasks completed =  79 remaining task =  0
#
# Total cost = 488.0
#
# Worker 1 assigned to task 8 sku AA0022 Cost = 35                                     start time = Fri Jun  4 08:00:00 2021 , end time = Fri Jun  4 08:35:00 2021
# Worker 2 assigned to task 9 sku AA0026 Cost = 37                                     start time = Fri Jun  4 08:00:00 2021 , end time = Fri Jun  4 08:37:00 2021
# Worker 3 assigned to task 11 sku AA0029 Cost = 34                                     start time = Fri Jun  4 08:00:00 2021 , end time = Fri Jun  4 08:34:00 2021
# Worker 4 assigned to task 1 sku AA0007 Cost = 39                                     start time = Fri Jun  4 08:00:00 2021 , end time = Fri Jun  4 08:39:00 2021
# Worker 5 assigned to task 4 sku AA0011 Cost = 34                                     start time = Fri Jun  4 08:00:00 2021 , end time = Fri Jun  4 08:34:00 2021
# Worker 6 assigned to task 0 sku AA0005 Cost = 41                                     start time = Fri Jun  4 08:00:00 2021 , end time = Fri Jun  4 08:41:00 2021
# Worker 7 assigned to task 10 sku AA0028 Cost = 56                                     start time = Fri Jun  4 08:00:00 2021 , end time = Fri Jun  4 08:56:00 2021
# Worker 8 assigned to task 6 sku AA0018 Cost = 37                                     start time = Fri Jun  4 08:00:00 2021 , end time = Fri Jun  4 08:37:00 2021
# Worker 9 assigned to task 2 sku AA0008 Cost = 49                                     start time = Fri Jun  4 08:00:00 2021 , end time = Fri Jun  4 08:49:00 2021
# Worker 10 assigned to task 7 sku AA0021 Cost = 39                                     start time = Fri Jun  4 08:00:00 2021 , end time = Fri Jun  4 08:39:00 2021
# Worker 11 assigned to task 5 sku AA0017 Cost = 50                                     start time = Fri Jun  4 08:00:00 2021 , end time = Fri Jun  4 08:50:00 2021
# Worker 12 assigned to task 3 sku AA0009 Cost = 37                                     start time = Fri Jun  4 08:00:00 2021 , end time = Fri Jun  4 08:37:00 2021
# total tasks completed =  12 remaining task =  72
#
# Total cost = 466.0
#
# Worker 1 assigned to task 16 sku AA0044 Cost = 36                                     start time = Fri Jun  4 08:35:00 2021 , end time = Fri Jun  4 09:11:00 2021
# Worker 2 assigned to task 18 sku AA0050 Cost = 33                                     start time = Fri Jun  4 08:37:00 2021 , end time = Fri Jun  4 09:10:00 2021
# Worker 3 assigned to task 22 sku AA0059 Cost = 43                                     start time = Fri Jun  4 08:34:00 2021 , end time = Fri Jun  4 09:17:00 2021
# Worker 4 assigned to task 23 sku AA0060 Cost = 34                                     start time = Fri Jun  4 08:39:00 2021 , end time = Fri Jun  4 09:13:00 2021
# Worker 5 assigned to task 17 sku AA0048 Cost = 35                                     start time = Fri Jun  4 08:34:00 2021 , end time = Fri Jun  4 09:09:00 2021
# Worker 6 assigned to task 14 sku AA0039 Cost = 39                                     start time = Fri Jun  4 08:41:00 2021 , end time = Fri Jun  4 09:20:00 2021
# Worker 7 assigned to task 13 sku AA0033 Cost = 35                                     start time = Fri Jun  4 08:56:00 2021 , end time = Fri Jun  4 09:31:00 2021
# Worker 8 assigned to task 12 sku AA0031 Cost = 40                                     start time = Fri Jun  4 08:37:00 2021 , end time = Fri Jun  4 09:17:00 2021
# Worker 9 assigned to task 21 sku AA0058 Cost = 40                                     start time = Fri Jun  4 08:49:00 2021 , end time = Fri Jun  4 09:29:00 2021
# Worker 10 assigned to task 15 sku AA0041 Cost = 50                                     start time = Fri Jun  4 08:39:00 2021 , end time = Fri Jun  4 09:29:00 2021
# Worker 11 assigned to task 19 sku AA0054 Cost = 43                                     start time = Fri Jun  4 08:50:00 2021 , end time = Fri Jun  4 09:33:00 2021
# Worker 12 assigned to task 20 sku AA0055 Cost = 38                                     start time = Fri Jun  4 08:37:00 2021 , end time = Fri Jun  4 09:15:00 2021
# total tasks completed =  24 remaining task =  60
#
# Total cost = 475.0
#
# Worker 1 assigned to task 24 sku AA0061 Cost = 34                                     start time = Fri Jun  4 09:11:00 2021 , end time = Fri Jun  4 09:45:00 2021
# Worker 2 assigned to task 30 sku AA0074 Cost = 48                                     start time = Fri Jun  4 09:10:00 2021 , end time = Fri Jun  4 09:58:00 2021
# Worker 3 assigned to task 34 sku AA0086 Cost = 39                                     start time = Fri Jun  4 09:17:00 2021 , end time = Fri Jun  4 09:56:00 2021
# Worker 4 assigned to task 28 sku AA0071 Cost = 40                                     start time = Fri Jun  4 09:13:00 2021 , end time = Fri Jun  4 09:53:00 2021
# Worker 5 assigned to task 32 sku AA0083 Cost = 38                                     start time = Fri Jun  4 09:09:00 2021 , end time = Fri Jun  4 09:47:00 2021
# Worker 6 assigned to task 27 sku AA0066 Cost = 39                                     start time = Fri Jun  4 09:20:00 2021 , end time = Fri Jun  4 09:59:00 2021
# Worker 7 assigned to task 31 sku AA0077 Cost = 47                                     start time = Fri Jun  4 09:31:00 2021 , end time = Fri Jun  4 10:18:00 2021
# Worker 8 assigned to task 29 sku AA0073 Cost = 40                                     start time = Fri Jun  4 09:17:00 2021 , end time = Fri Jun  4 09:57:00 2021
# Worker 9 assigned to task 35 sku AA0088 Cost = 41                                     start time = Fri Jun  4 09:29:00 2021 , end time = Fri Jun  4 10:10:00 2021
# Worker 10 assigned to task 26 sku AA0064 Cost = 39                                     start time = Fri Jun  4 09:29:00 2021 , end time = Fri Jun  4 10:08:00 2021
# Worker 11 assigned to task 33 sku AA0085 Cost = 33                                     start time = Fri Jun  4 09:33:00 2021 , end time = Fri Jun  4 10:06:00 2021
# Worker 12 assigned to task 25 sku AA0063 Cost = 37                                     start time = Fri Jun  4 09:15:00 2021 , end time = Fri Jun  4 09:52:00 2021
# total tasks completed =  36 remaining task =  48
#
# Total cost = 461.0
#
# Worker 1 assigned to task 39 sku AA0099 Cost = 39                                     start time = Fri Jun  4 09:45:00 2021 , end time = Fri Jun  4 10:24:00 2021
# Worker 2 assigned to task 43 sku AA0117 Cost = 41                                     start time = Fri Jun  4 09:58:00 2021 , end time = Fri Jun  4 10:39:00 2021
# Worker 3 assigned to task 38 sku AA0095 Cost = 31                                     start time = Fri Jun  4 09:56:00 2021 , end time = Fri Jun  4 10:27:00 2021
# Worker 4 assigned to task 41 sku AA0102 Cost = 44                                     start time = Fri Jun  4 09:53:00 2021 , end time = Fri Jun  4 10:37:00 2021
# Worker 5 assigned to task 37 sku AA0093 Cost = 45                                     start time = Fri Jun  4 09:47:00 2021 , end time = Fri Jun  4 10:32:00 2021
# Worker 6 assigned to task 47 sku AA0123 Cost = 36                                     start time = Fri Jun  4 09:59:00 2021 , end time = Fri Jun  4 10:35:00 2021
# Worker 7 assigned to task 42 sku AA0105 Cost = 37                                     start time = Fri Jun  4 10:18:00 2021 , end time = Fri Jun  4 10:55:00 2021
# Worker 8 assigned to task 44 sku AA0119 Cost = 38                                     start time = Fri Jun  4 09:57:00 2021 , end time = Fri Jun  4 10:35:00 2021
# Worker 9 assigned to task 45 sku AA0121 Cost = 40                                     start time = Fri Jun  4 10:10:00 2021 , end time = Fri Jun  4 10:50:00 2021
# Worker 10 assigned to task 40 sku AA0100 Cost = 33                                     start time = Fri Jun  4 10:08:00 2021 , end time = Fri Jun  4 10:41:00 2021
# Worker 11 assigned to task 36 sku AA0090 Cost = 46                                     start time = Fri Jun  4 10:06:00 2021 , end time = Fri Jun  4 10:52:00 2021
# Worker 12 assigned to task 46 sku AA0122 Cost = 31                                     start time = Fri Jun  4 09:52:00 2021 , end time = Fri Jun  4 10:23:00 2021
# total tasks completed =  48 remaining task =  36
#
# Total cost = 491.0
#
# Worker 1 assigned to task 59 sku AA0153 Cost = 38                                     start time = Fri Jun  4 10:24:00 2021 , end time = Fri Jun  4 11:02:00 2021
# Worker 2 assigned to task 48 sku AA0125 Cost = 37                                     start time = Fri Jun  4 10:39:00 2021 , end time = Fri Jun  4 11:16:00 2021
# Worker 3 assigned to task 57 sku AA0149 Cost = 37                                     start time = Fri Jun  4 10:27:00 2021 , end time = Fri Jun  4 11:04:00 2021
# ...
# Worker 9 assigned to task 29 sku AA0051 Cost = 47                                     start time = Wed Jun 30 09:29:00 2021 , end time = Wed Jun 30 10:16:00 2021
# Worker 10 assigned to task 25 sku AA0043 Cost = 39                                     start time = Wed Jun 30 09:17:00 2021 , end time = Wed Jun 30 09:56:00 2021
# Worker 11 assigned to task 34 sku AA0057 Cost = 40                                     start time = Wed Jun 30 09:27:00 2021 , end time = Wed Jun 30 10:07:00 2021
# Worker 12 assigned to task 32 sku AA0055 Cost = 36                                     start time = Wed Jun 30 09:20:00 2021 , end time = Wed Jun 30 09:56:00 2021
# total tasks completed =  36 remaining task =  90
#
# Total cost = 514.0
#
# Worker 1 assigned to task 37 sku AA0061 Cost = 45                                     start time = Wed Jun 30 09:59:00 2021 , end time = Wed Jun 30 10:44:00 2021
# Worker 2 assigned to task 44 sku AA0074 Cost = 49                                     start time = Wed Jun 30 09:55:00 2021 , end time = Wed Jun 30 10:44:00 2021
# Worker 3 assigned to task 36 sku AA0059 Cost = 40                                     start time = Wed Jun 30 10:11:00 2021 , end time = Wed Jun 30 10:51:00 2021
# Worker 4 assigned to task 40 sku AA0067 Cost = 45                                     start time = Wed Jun 30 09:59:00 2021 , end time = Wed Jun 30 10:44:00 2021
# Worker 5 assigned to task 45 sku AA0075 Cost = 41                                     start time = Wed Jun 30 09:57:00 2021 , end time = Wed Jun 30 10:38:00 2021
# Worker 6 assigned to task 46 sku AA0076 Cost = 47                                     start time = Wed Jun 30 10:03:00 2021 , end time = Wed Jun 30 10:50:00 2021
# Worker 7 assigned to task 41 sku AA0068 Cost = 45                                     start time = Wed Jun 30 09:56:00 2021 , end time = Wed Jun 30 10:41:00 2021
# Worker 8 assigned to task 43 sku AA0073 Cost = 38                                     start time = Wed Jun 30 09:56:00 2021 , end time = Wed Jun 30 10:34:00 2021
# Worker 9 assigned to task 42 sku AA0070 Cost = 45                                     start time = Wed Jun 30 10:16:00 2021 , end time = Wed Jun 30 11:01:00 2021
# Worker 10 assigned to task 47 sku AA0077 Cost = 47                                     start time = Wed Jun 30 09:56:00 2021 , end time = Wed Jun 30 10:43:00 2021
# Worker 11 assigned to task 39 sku AA0066 Cost = 33                                     start time = Wed Jun 30 10:07:00 2021 , end time = Wed Jun 30 10:40:00 2021
# Worker 12 assigned to task 38 sku AA0063 Cost = 39                                     start time = Wed Jun 30 09:56:00 2021 , end time = Wed Jun 30 10:35:00 2021
# total tasks completed =  48 remaining task =  78
#
# Total cost = 484.0
#
# Worker 1 assigned to task 53 sku AA0086 Cost = 49                                     start time = Wed Jun 30 10:44:00 2021 , end time = Wed Jun 30 11:33:00 2021
# Worker 2 assigned to task 50 sku AA0082 Cost = 38                                     start time = Wed Jun 30 10:44:00 2021 , end time = Wed Jun 30 11:22:00 2021
# Worker 3 assigned to task 58 sku AA0095 Cost = 31                                     start time = Wed Jun 30 10:51:00 2021 , end time = Wed Jun 30 11:22:00 2021
# Worker 4 assigned to task 49 sku AA0081 Cost = 36                                     start time = Wed Jun 30 10:44:00 2021 , end time = Wed Jun 30 11:20:00 2021
# Worker 5 assigned to task 59 sku AA0098 Cost = 33                                     start time = Wed Jun 30 10:38:00 2021 , end time = Wed Jun 30 11:11:00 2021
# Worker 6 assigned to task 52 sku AA0084 Cost = 34                                     start time = Wed Jun 30 10:50:00 2021 , end time = Wed Jun 30 11:24:00 2021
# Worker 7 assigned to task 57 sku AA0094 Cost = 47                                     start time = Wed Jun 30 10:41:00 2021 , end time = Wed Jun 30 11:28:00 2021
# Worker 8 assigned to task 51 sku AA0083 Cost = 63                                     start time = Wed Jun 30 10:34:00 2021 , end time = Wed Jun 30 11:37:00 2021
# Worker 9 assigned to task 54 sku AA0087 Cost = 33                                     start time = Wed Jun 30 11:01:00 2021 , end time = Wed Jun 30 11:34:00 2021
# Worker 10 assigned to task 48 sku AA0079 Cost = 43                                     start time = Wed Jun 30 10:43:00 2021 , end time = Wed Jun 30 11:26:00 2021
# Worker 11 assigned to task 56 sku AA0092 Cost = 38                                     start time = Wed Jun 30 10:40:00 2021 , end time = Wed Jun 30 11:18:00 2021
# Worker 12 assigned to task 55 sku AA0089 Cost = 39                                     start time = Wed Jun 30 10:35:00 2021 , end time = Wed Jun 30 11:14:00 2021
# total tasks completed =  60 remaining task =  66
#
# Total cost = 471.0
#
# Worker 1 assigned to task 70 sku AA0110 Cost = 36                                     start time = Wed Jun 30 11:33:00 2021 , end time = Wed Jun 30 12:09:00 2021
# Worker 2 assigned to task 63 sku AA0102 Cost = 38                                     start time = Wed Jun 30 11:22:00 2021 , end time = Wed Jun 30 12:00:00 2021
# Worker 3 assigned to task 64 sku AA0103 Cost = 48                                     start time = Wed Jun 30 11:22:00 2021 , end time = Wed Jun 30 12:10:00 2021
# Worker 4 assigned to task 68 sku AA0108 Cost = 37                                     start time = Wed Jun 30 11:20:00 2021 , end time = Wed Jun 30 11:57:00 2021
# Worker 5 assigned to task 60 sku AA0099 Cost = 38                                     start time = Wed Jun 30 11:11:00 2021 , end time = Wed Jun 30 11:49:00 2021
# Worker 6 assigned to task 65 sku AA0104 Cost = 39                                     start time = Wed Jun 30 11:24:00 2021 , end time = Wed Jun 30 12:03:00 2021
# Worker 7 assigned to task 66 sku AA0105 Cost = 38                                     start time = Wed Jun 30 11:28:00 2021 , end time = Wed Jun 30 12:06:00 2021
# Worker 8 assigned to task 69 sku AA0109 Cost = 40                                     start time = Wed Jun 30 11:37:00 2021 , end time = Wed Jun 30 12:17:00 2021
# Worker 9 assigned to task 71 sku AA0113 Cost = 42                                     start time = Wed Jun 30 11:34:00 2021 , end time = Wed Jun 30 12:16:00 2021
# Worker 10 assigned to task 61 sku AA0100 Cost = 33                                     start time = Wed Jun 30 11:26:00 2021 , end time = Wed Jun 30 11:59:00 2021
# Worker 11 assigned to task 67 sku AA0106 Cost = 44                                     start time = Wed Jun 30 11:18:00 2021 , end time = Wed Jun 30 12:02:00 2021
# Worker 12 assigned to task 62 sku AA0101 Cost = 38                                     start time = Wed Jun 30 11:14:00 2021 , end time = Wed Jun 30 11:52:00 2021
# total tasks completed =  72 remaining task =  54
#
# Total cost = 488.0
#
# Worker 1 assigned to task 76 sku AA0120 Cost = 47                                     start time = Wed Jun 30 12:09:00 2021 , end time = Wed Jun 30 12:56:00 2021
# Worker 2 assigned to task 74 sku AA0117 Cost = 35                                     start time = Wed Jun 30 12:00:00 2021 , end time = Wed Jun 30 12:35:00 2021
# Worker 3 assigned to task 73 sku AA0116 Cost = 43                                     start time = Wed Jun 30 12:10:00 2021 , end time = Wed Jun 30 12:53:00 2021
# Worker 4 assigned to task 78 sku AA0124 Cost = 53                                     start time = Wed Jun 30 11:57:00 2021 , end time = Wed Jun 30 12:50:00 2021
# Worker 5 assigned to task 77 sku AA0121 Cost = 42                                     start time = Wed Jun 30 11:49:00 2021 , end time = Wed Jun 30 12:31:00 2021
# Worker 6 assigned to task 72 sku AA0115 Cost = 38                                     start time = Wed Jun 30 12:03:00 2021 , end time = Wed Jun 30 12:41:00 2021
# Worker 7 assigned to task 82 sku AA0131 Cost = 40                                     start time = Wed Jun 30 12:06:00 2021 , end time = Wed Jun 30 12:46:00 2021
# Worker 8 assigned to task 80 sku AA0126 Cost = 45                                     start time = Wed Jun 30 12:17:00 2021 , end time = Wed Jun 30 13:02:00 2021
# Worker 9 assigned to task 81 sku AA0128 Cost = 29                                     start time = Wed Jun 30 12:16:00 2021 , end time = Wed Jun 30 12:45:00 2021
# Worker 10 assigned to task 83 sku AA0132 Cost = 42                                     start time = Wed Jun 30 11:59:00 2021 , end time = Wed Jun 30 12:41:00 2021
# Worker 11 assigned to task 75 sku AA0118 Cost = 41                                     start time = Wed Jun 30 12:02:00 2021 , end time = Wed Jun 30 12:43:00 2021
# Worker 12 assigned to task 79 sku AA0125 Cost = 33                                     start time = Wed Jun 30 11:52:00 2021 , end time = Wed Jun 30 12:25:00 2021
# total tasks completed =  84 remaining task =  42
#
# Total cost = 498.0
#
# Worker 1 assigned to task 93 sku AA0148 Cost = 40                                     start time = Wed Jun 30 12:56:00 2021 , end time = Wed Jun 30 13:36:00 2021
# Worker 2 assigned to task 86 sku AA0138 Cost = 38                                     start time = Wed Jun 30 12:35:00 2021 , end time = Wed Jun 30 13:13:00 2021
# Worker 3 assigned to task 94 sku AA0149 Cost = 40                                     start time = Wed Jun 30 12:53:00 2021 , end time = Wed Jun 30 13:33:00 2021
# Worker 4 assigned to task 89 sku AA0144 Cost = 38                                     start time = Wed Jun 30 12:50:00 2021 , end time = Wed Jun 30 13:28:00 2021
# Worker 5 assigned to task 88 sku AA0142 Cost = 42                                     start time = Wed Jun 30 12:31:00 2021 , end time = Wed Jun 30 13:13:00 2021
# Worker 6 assigned to task 91 sku AA0146 Cost = 48                                     start time = Wed Jun 30 12:41:00 2021 , end time = Wed Jun 30 13:29:00 2021
# Worker 7 assigned to task 95 sku AA0150 Cost = 47                                     start time = Wed Jun 30 12:46:00 2021 , end time = Wed Jun 30 13:33:00 2021
# Worker 8 assigned to task 92 sku AA0147 Cost = 35                                     start time = Wed Jun 30 13:02:00 2021 , end time = Wed Jun 30 13:37:00 2021
# Worker 9 assigned to task 85 sku AA0135 Cost = 41                                     start time = Wed Jun 30 12:45:00 2021 , end time = Wed Jun 30 13:26:00 2021
# Worker 10 assigned to task 87 sku AA0141 Cost = 54                                     start time = Wed Jun 30 12:41:00 2021 , end time = Wed Jun 30 13:35:00 2021
# Worker 11 assigned to task 84 sku AA0133 Cost = 32                                     start time = Wed Jun 30 12:43:00 2021 , end time = Wed Jun 30 13:15:00 2021
# Worker 12 assigned to task 90 sku AA0145 Cost = 43                                     start time = Wed Jun 30 12:25:00 2021 , end time = Wed Jun 30 13:08:00 2021
# total tasks completed =  96 remaining task =  30
#
# Total cost = 467.0
#
# Worker 1 assigned to task 100 sku AA0160 Cost = 41                                     start time = Wed Jun 30 13:36:00 2021 , end time = Wed Jun 30 14:17:00 2021
# Worker 2 assigned to task 97 sku AA0155 Cost = 35                                     start time = Wed Jun 30 13:13:00 2021 , end time = Wed Jun 30 13:48:00 2021
# Worker 3 assigned to task 104 sku AA0165 Cost = 36                                     start time = Wed Jun 30 13:33:00 2021 , end time = Wed Jun 30 14:09:00 2021
# Worker 4 assigned to task 96 sku AA0152 Cost = 43                                     start time = Wed Jun 30 13:28:00 2021 , end time = Wed Jun 30 14:11:00 2021
# Worker 5 assigned to task 107 sku AA0171 Cost = 36                                     start time = Wed Jun 30 13:13:00 2021 , end time = Wed Jun 30 13:49:00 2021
# Worker 6 assigned to task 98 sku AA0156 Cost = 42                                     start time = Wed Jun 30 13:29:00 2021 , end time = Wed Jun 30 14:11:00 2021
# Worker 7 assigned to task 103 sku AA0164 Cost = 32                                     start time = Wed Jun 30 13:33:00 2021 , end time = Wed Jun 30 14:05:00 2021
# Worker 8 assigned to task 101 sku AA0161 Cost = 46                                     start time = Wed Jun 30 13:37:00 2021 , end time = Wed Jun 30 14:23:00 2021
# Worker 9 assigned to task 105 sku AA0166 Cost = 37                                     start time = Wed Jun 30 13:26:00 2021 , end time = Wed Jun 30 14:03:00 2021
# Worker 10 assigned to task 102 sku AA0162 Cost = 37                                     start time = Wed Jun 30 13:35:00 2021 , end time = Wed Jun 30 14:12:00 2021
# Worker 11 assigned to task 99 sku AA0158 Cost = 43                                     start time = Wed Jun 30 13:15:00 2021 , end time = Wed Jun 30 13:58:00 2021
# Worker 12 assigned to task 106 sku AA0167 Cost = 39                                     start time = Wed Jun 30 13:08:00 2021 , end time = Wed Jun 30 13:47:00 2021
# total tasks completed =  108 remaining task =  18
#
# Total cost = 461.0
#
# Worker 1 assigned to task 119 sku AA0192 Cost = 36                                     start time = Wed Jun 30 14:17:00 2021 , end time = Wed Jun 30 14:53:00 2021
# Worker 2 assigned to task 116 sku AA0187 Cost = 37                                     start time = Wed Jun 30 13:48:00 2021 , end time = Wed Jun 30 14:25:00 2021
# Worker 3 assigned to task 109 sku AA0174 Cost = 33                                     start time = Wed Jun 30 14:09:00 2021 , end time = Wed Jun 30 14:42:00 2021
# Worker 4 assigned to task 115 sku AA0186 Cost = 38                                     start time = Wed Jun 30 14:11:00 2021 , end time = Wed Jun 30 14:49:00 2021
# Worker 5 assigned to task 113 sku AA0180 Cost = 42                                     start time = Wed Jun 30 13:49:00 2021 , end time = Wed Jun 30 14:31:00 2021
# Worker 6 assigned to task 110 sku AA0175 Cost = 50                                     start time = Wed Jun 30 14:11:00 2021 , end time = Wed Jun 30 15:01:00 2021
# Worker 7 assigned to task 112 sku AA0177 Cost = 28                                     start time = Wed Jun 30 14:05:00 2021 , end time = Wed Jun 30 14:33:00 2021
# Worker 8 assigned to task 117 sku AA0189 Cost = 43                                     start time = Wed Jun 30 14:23:00 2021 , end time = Wed Jun 30 15:06:00 2021
# Worker 9 assigned to task 108 sku AA0172 Cost = 36                                     start time = Wed Jun 30 14:03:00 2021 , end time = Wed Jun 30 14:39:00 2021
# Worker 10 assigned to task 111 sku AA0176 Cost = 39                                     start time = Wed Jun 30 14:12:00 2021 , end time = Wed Jun 30 14:51:00 2021
# Worker 11 assigned to task 118 sku AA0191 Cost = 42                                     start time = Wed Jun 30 13:58:00 2021 , end time = Wed Jun 30 14:40:00 2021
# Worker 12 assigned to task 114 sku AA0185 Cost = 37                                     start time = Wed Jun 30 13:47:00 2021 , end time = Wed Jun 30 14:24:00 2021
# total tasks completed =  120 remaining task =  6
#
# Total cost = 228.0
#
# Worker 1 assigned to task 122 sku AA0195 Cost = 48                                     start time = Wed Jun 30 14:53:00 2021 end time = Wed Jun 30 15:41:00 2021
# Worker 2 assigned to task 121 sku AA0194 Cost = 36                                     start time = Wed Jun 30 14:25:00 2021 end time = Wed Jun 30 15:01:00 2021
# Worker 8 assigned to task 120 sku AA0193 Cost = 35                                     start time = Wed Jun 30 15:06:00 2021 end time = Wed Jun 30 15:41:00 2021
# Worker 9 assigned to task 124 sku AA0199 Cost = 36                                     start time = Wed Jun 30 14:39:00 2021 end time = Wed Jun 30 15:15:00 2021
# Worker 10 assigned to task 125 sku AA0200 Cost = 37                                     start time = Wed Jun 30 14:51:00 2021 end time = Wed Jun 30 15:28:00 2021
# Worker 11 assigned to task 123 sku AA0198 Cost = 36                                     start time = Wed Jun 30 14:40:00 2021 end time = Wed Jun 30 15:16:00 2021
# total tasks completed =  126 remaining task =  0

# %%
# 9, this script perform the assignment but without optimisation

# from ortools.sat.python import cp_model
import csv
import datetime
from datetime import timedelta
import pandas as pd


w = [('1', datetime.datetime(2021, 6, 1, hour=8)), 
    ('2', datetime.datetime(2021, 6, 2, hour=8)),
    ('3', datetime.datetime(2021, 6, 3, hour=8)),
    ('4', datetime.datetime(2021, 6, 4, hour=8)),
    ('5', datetime.datetime(2021, 6, 7, hour=8)),
    ('6', datetime.datetime(2021, 6, 8, hour=8)),
    ('7', datetime.datetime(2021, 6, 9, hour=8)),
    ('8', datetime.datetime(2021, 6, 10, hour=8)),
    ('9', datetime.datetime(2021, 6, 11, hour=8)),
    ('10', datetime.datetime(2021, 6, 14, hour=8)),
    ('11', datetime.datetime(2021, 6, 15, hour=8)),
    ('12', datetime.datetime(2021, 6, 16, hour=8)),
    ('13', datetime.datetime(2021, 6, 17, hour=8)),
    ('14', datetime.datetime(2021, 6, 18, hour=8)),
    ('15', datetime.datetime(2021, 6, 21, hour=8)),
    ('16', datetime.datetime(2021, 6, 22, hour=8)),
    ('17', datetime.datetime(2021, 6, 23, hour=8)),
    ('18', datetime.datetime(2021, 6, 24, hour=8)),
    ('19', datetime.datetime(2021, 6, 25, hour=8)),
    ('20', datetime.datetime(2021, 6, 28, hour=8)),
    ('21', datetime.datetime(2021, 6, 29, hour=8)),
    ('22', datetime.datetime(2021, 6, 30, hour=8)),
    ]


# with open('task_worker_mins.csv', newline='') as f:
#     data = [list(map(int,rec)) for rec in csv.reader(f)]

#workers_pdty = pd.read_csv("dropzone_workers_productivity1.csv", index_col=False)


def main():
    for u, v in w:
        workers_pdty= pd.read_sql('SELECT * from processed_workers_productivity'+u, con = engine)
        workers_pdty1 = workers_pdty.dropna(how='all', axis=1).astype(int)
        skujoblist = list(workers_pdty1.columns.values)  # list of sku to be picked in this batch

        data = workers_pdty1.values.tolist()

        # Assign
        team_size = []
        assign_worker = []
        assign_task = []
        skujob = []
        assign_time = []
        start_time = v

        # Data
        costs = data
        num_workers = len(costs)
        total_tasks = len(costs[0])
        k = 0

        assign_timestamp_start = [start_time] * num_workers
        assign_timestamp_end = [start_time] * num_workers

        while total_tasks > num_workers:
            num_tasks = num_workers
            for i in range(num_workers):
                start_time = assign_timestamp_end[k+i]
                end_time = start_time + timedelta(minutes=costs[i][i+k])
                team_size.append(num_worker)
                assign_worker.append('W'+str(i+1).zfill(3))
                assign_task.append(i+k)
                skujob.append(skujoblist[i+k])
                assign_time.append(costs[i][i+k])
                assign_timestamp_start.append(start_time)
                assign_timestamp_end.append(end_time)
                print(
                    f'Worker {i+1} assigned to task {i+k} sku {skujoblist[i+k]} Cost = {costs[i][i+k]} \
                        start time = {start_time.strftime("%c")} , end time = {end_time.strftime("%c")}')
        
            total_tasks = total_tasks - num_tasks
            k = k + num_tasks
            print('total tasks completed = ', k, 'remaining task = ', total_tasks, '\n')

        else:
            num_tasks = total_tasks
            for i in range(num_tasks):
                start_time = assign_timestamp_end[k+i]
                end_time = start_time + timedelta(minutes=costs[i][i+k])
                team_size.append(num_worker)
                assign_worker.append('W'+str(i+1).zfill(3))
                assign_task.append(i+k)
                skujob.append(skujoblist[i+k])
                assign_time.append(costs[i][i+k])
                assign_timestamp_start.append(start_time)
                assign_timestamp_end.append(end_time)
                print(
                    f'Worker {i+1} assigned to task {i+k} sku {skujoblist[i+k]} Cost = {costs[i][i+k]} \
                        start time = {start_time.strftime("%c")} end time = {end_time.strftime("%c")}')

            total_tasks = total_tasks - num_tasks
            k = k + num_tasks
            print('total tasks completed = ', k, 'remaining task = ', total_tasks, '\n')

        assign_timestamp_start = [i for i in assign_timestamp_start [num_workers:]]
        assign_timestamp_end = [i for i in assign_timestamp_end [num_workers:]]
        res = list(zip(team_size, assign_worker, assign_task, skujob, assign_time, assign_timestamp_start, assign_timestamp_end))
        # print(res)

        # with open('task_result2.csv', 'w') as f:
        #     writer = csv.writer(f, delimiter=',', lineterminator='\n')
        #     writer.writerows(res)

        res_df = pd.DataFrame(res, columns=['team_size', 'assign_worker', 'assign_task', 'skujob', 'assign_time', \
            'assign_timestamp_start', 'assign_timestamp_end'])
        # print(res_df)
        res_df.to_sql("job_assignment_result_noopt", engine, if_exists="append", index=False)

if __name__ == '__main__':
    main()
# Out:
# Worker 1 assigned to task 0 sku AA0008 Cost = 46                         start time = Tue Jun  1 08:00:00 2021 , end time = Tue Jun  1 08:46:00 2021
# Worker 2 assigned to task 1 sku AA0010 Cost = 45                         start time = Tue Jun  1 08:00:00 2021 , end time = Tue Jun  1 08:45:00 2021
# Worker 3 assigned to task 2 sku AA0016 Cost = 43                         start time = Tue Jun  1 08:00:00 2021 , end time = Tue Jun  1 08:43:00 2021
# Worker 4 assigned to task 3 sku AA0024 Cost = 44                         start time = Tue Jun  1 08:00:00 2021 , end time = Tue Jun  1 08:44:00 2021
# Worker 5 assigned to task 4 sku AA0039 Cost = 40                         start time = Tue Jun  1 08:00:00 2021 , end time = Tue Jun  1 08:40:00 2021
# Worker 6 assigned to task 5 sku AA0051 Cost = 41                         start time = Tue Jun  1 08:00:00 2021 , end time = Tue Jun  1 08:41:00 2021
# Worker 7 assigned to task 6 sku AA0057 Cost = 45                         start time = Tue Jun  1 08:00:00 2021 , end time = Tue Jun  1 08:45:00 2021
# Worker 8 assigned to task 7 sku AA0063 Cost = 42                         start time = Tue Jun  1 08:00:00 2021 , end time = Tue Jun  1 08:42:00 2021
# Worker 9 assigned to task 8 sku AA0067 Cost = 45                         start time = Tue Jun  1 08:00:00 2021 , end time = Tue Jun  1 08:45:00 2021
# Worker 10 assigned to task 9 sku AA0072 Cost = 39                         start time = Tue Jun  1 08:00:00 2021 , end time = Tue Jun  1 08:39:00 2021
# Worker 11 assigned to task 10 sku AA0075 Cost = 44                         start time = Tue Jun  1 08:00:00 2021 , end time = Tue Jun  1 08:44:00 2021
# Worker 12 assigned to task 11 sku AA0076 Cost = 58                         start time = Tue Jun  1 08:00:00 2021 , end time = Tue Jun  1 08:58:00 2021
# total tasks completed =  12 remaining task =  34
#
# Worker 1 assigned to task 12 sku AA0084 Cost = 35                         start time = Tue Jun  1 08:46:00 2021 , end time = Tue Jun  1 09:21:00 2021
# Worker 2 assigned to task 13 sku AA0086 Cost = 39                         start time = Tue Jun  1 08:45:00 2021 , end time = Tue Jun  1 09:24:00 2021
# Worker 3 assigned to task 14 sku AA0087 Cost = 44                         start time = Tue Jun  1 08:43:00 2021 , end time = Tue Jun  1 09:27:00 2021
# Worker 4 assigned to task 15 sku AA0089 Cost = 41                         start time = Tue Jun  1 08:44:00 2021 , end time = Tue Jun  1 09:25:00 2021
# Worker 5 assigned to task 16 sku AA0091 Cost = 47                         start time = Tue Jun  1 08:40:00 2021 , end time = Tue Jun  1 09:27:00 2021
# Worker 6 assigned to task 17 sku AA0099 Cost = 43                         start time = Tue Jun  1 08:41:00 2021 , end time = Tue Jun  1 09:24:00 2021
# Worker 7 assigned to task 18 sku AA0103 Cost = 46                         start time = Tue Jun  1 08:45:00 2021 , end time = Tue Jun  1 09:31:00 2021
# Worker 8 assigned to task 19 sku AA0105 Cost = 37                         start time = Tue Jun  1 08:42:00 2021 , end time = Tue Jun  1 09:19:00 2021
# Worker 9 assigned to task 20 sku AA0107 Cost = 46                         start time = Tue Jun  1 08:45:00 2021 , end time = Tue Jun  1 09:31:00 2021
# Worker 10 assigned to task 21 sku AA0109 Cost = 48                         start time = Tue Jun  1 08:39:00 2021 , end time = Tue Jun  1 09:27:00 2021
# Worker 11 assigned to task 22 sku AA0112 Cost = 42                         start time = Tue Jun  1 08:44:00 2021 , end time = Tue Jun  1 09:26:00 2021
# Worker 12 assigned to task 23 sku AA0114 Cost = 43                         start time = Tue Jun  1 08:58:00 2021 , end time = Tue Jun  1 09:41:00 2021
# total tasks completed =  24 remaining task =  22
#
# Worker 1 assigned to task 24 sku AA0116 Cost = 42                         start time = Tue Jun  1 09:21:00 2021 , end time = Tue Jun  1 10:03:00 2021
# Worker 2 assigned to task 25 sku AA0117 Cost = 33                         start time = Tue Jun  1 09:24:00 2021 , end time = Tue Jun  1 09:57:00 2021
# Worker 3 assigned to task 26 sku AA0119 Cost = 52                         start time = Tue Jun  1 09:27:00 2021 , end time = Tue Jun  1 10:19:00 2021
# Worker 4 assigned to task 27 sku AA0122 Cost = 45                         start time = Tue Jun  1 09:25:00 2021 , end time = Tue Jun  1 10:10:00 2021
# Worker 5 assigned to task 28 sku AA0129 Cost = 45                         start time = Tue Jun  1 09:27:00 2021 , end time = Tue Jun  1 10:12:00 2021
# Worker 6 assigned to task 29 sku AA0131 Cost = 45                         start time = Tue Jun  1 09:24:00 2021 , end time = Tue Jun  1 10:09:00 2021
# Worker 7 assigned to task 30 sku AA0133 Cost = 36                         start time = Tue Jun  1 09:31:00 2021 , end time = Tue Jun  1 10:07:00 2021
# Worker 8 assigned to task 31 sku AA0142 Cost = 43                         start time = Tue Jun  1 09:19:00 2021 , end time = Tue Jun  1 10:02:00 2021
# Worker 9 assigned to task 32 sku AA0144 Cost = 44                         start time = Tue Jun  1 09:31:00 2021 , end time = Tue Jun  1 10:15:00 2021
# Worker 10 assigned to task 33 sku AA0145 Cost = 41                         start time = Tue Jun  1 09:27:00 2021 , end time = Tue Jun  1 10:08:00 2021
# Worker 11 assigned to task 34 sku AA0146 Cost = 36                         start time = Tue Jun  1 09:26:00 2021 , end time = Tue Jun  1 10:02:00 2021
# Worker 12 assigned to task 35 sku AA0150 Cost = 45                         start time = Tue Jun  1 09:41:00 2021 , end time = Tue Jun  1 10:26:00 2021
# total tasks completed =  36 remaining task =  10
#
# Worker 1 assigned to task 36 sku AA0152 Cost = 41                         start time = Tue Jun  1 10:03:00 2021 end time = Tue Jun  1 10:44:00 2021
# Worker 2 assigned to task 37 sku AA0155 Cost = 36                         start time = Tue Jun  1 09:57:00 2021 end time = Tue Jun  1 10:33:00 2021
# Worker 3 assigned to task 38 sku AA0159 Cost = 45                         start time = Tue Jun  1 10:19:00 2021 end time = Tue Jun  1 11:04:00 2021
# Worker 4 assigned to task 39 sku AA0165 Cost = 34                         start time = Tue Jun  1 10:10:00 2021 end time = Tue Jun  1 10:44:00 2021
# Worker 5 assigned to task 40 sku AA0176 Cost = 40                         start time = Tue Jun  1 10:12:00 2021 end time = Tue Jun  1 10:52:00 2021
# Worker 6 assigned to task 41 sku AA0179 Cost = 35                         start time = Tue Jun  1 10:09:00 2021 end time = Tue Jun  1 10:44:00 2021
# Worker 7 assigned to task 42 sku AA0182 Cost = 36                         start time = Tue Jun  1 10:07:00 2021 end time = Tue Jun  1 10:43:00 2021
# Worker 8 assigned to task 43 sku AA0185 Cost = 38                         start time = Tue Jun  1 10:02:00 2021 end time = Tue Jun  1 10:40:00 2021
# Worker 9 assigned to task 44 sku AA0198 Cost = 40                         start time = Tue Jun  1 10:15:00 2021 end time = Tue Jun  1 10:55:00 2021
# Worker 10 assigned to task 45 sku AA0199 Cost = 39                         start time = Tue Jun  1 10:08:00 2021 end time = Tue Jun  1 10:47:00 2021
# total tasks completed =  46 remaining task =  0
#
# Worker 1 assigned to task 0 sku AA0006 Cost = 45                         start time = Wed Jun  2 08:00:00 2021 , end time = Wed Jun  2 08:45:00 2021
# Worker 2 assigned to task 1 sku AA0008 Cost = 51                         start time = Wed Jun  2 08:00:00 2021 , end time = Wed Jun  2 08:51:00 2021
# Worker 3 assigned to task 2 sku AA0010 Cost = 44                         start time = Wed Jun  2 08:00:00 2021 , end time = Wed Jun  2 08:44:00 2021
# Worker 4 assigned to task 3 sku AA0011 Cost = 47                         start time = Wed Jun  2 08:00:00 2021 , end time = Wed Jun  2 08:47:00 2021
# Worker 5 assigned to task 4 sku AA0012 Cost = 46                         start time = Wed Jun  2 08:00:00 2021 , end time = Wed Jun  2 08:46:00 2021
# Worker 6 assigned to task 5 sku AA0013 Cost = 44                         start time = Wed Jun  2 08:00:00 2021 , end time = Wed Jun  2 08:44:00 2021
# Worker 7 assigned to task 6 sku AA0015 Cost = 47                         start time = Wed Jun  2 08:00:00 2021 , end time = Wed Jun  2 08:47:00 2021
# Worker 8 assigned to task 7 sku AA0016 Cost = 40                         start time = Wed Jun  2 08:00:00 2021 , end time = Wed Jun  2 08:40:00 2021
# Worker 9 assigned to task 8 sku AA0018 Cost = 50                         start time = Wed Jun  2 08:00:00 2021 , end time = Wed Jun  2 08:50:00 2021
# Worker 10 assigned to task 9 sku AA0019 Cost = 45                         start time = Wed Jun  2 08:00:00 2021 , end time = Wed Jun  2 08:45:00 2021
# Worker 11 assigned to task 10 sku AA0020 Cost = 37                         start time = Wed Jun  2 08:00:00 2021 , end time = Wed Jun  2 08:37:00 2021
# Worker 12 assigned to task 11 sku AA0024 Cost = 41                         start time = Wed Jun  2 08:00:00 2021 , end time = Wed Jun  2 08:41:00 2021
# total tasks completed =  12 remaining task =  97
#
# Worker 1 assigned to task 12 sku AA0025 Cost = 37                         start time = Wed Jun  2 08:45:00 2021 , end time = Wed Jun  2 09:22:00 2021
# Worker 2 assigned to task 13 sku AA0026 Cost = 37                         start time = Wed Jun  2 08:51:00 2021 , end time = Wed Jun  2 09:28:00 2021
# Worker 3 assigned to task 14 sku AA0028 Cost = 46                         start time = Wed Jun  2 08:44:00 2021 , end time = Wed Jun  2 09:30:00 2021
# Worker 4 assigned to task 15 sku AA0029 Cost = 36                         start time = Wed Jun  2 08:47:00 2021 , end time = Wed Jun  2 09:23:00 2021
# Worker 5 assigned to task 16 sku AA0030 Cost = 39                         start time = Wed Jun  2 08:46:00 2021 , end time = Wed Jun  2 09:25:00 2021
# Worker 6 assigned to task 17 sku AA0032 Cost = 39                         start time = Wed Jun  2 08:44:00 2021 , end time = Wed Jun  2 09:23:00 2021
# Worker 7 assigned to task 18 sku AA0033 Cost = 37                         start time = Wed Jun  2 08:47:00 2021 , end time = Wed Jun  2 09:24:00 2021
# Worker 8 assigned to task 19 sku AA0036 Cost = 46                         start time = Wed Jun  2 08:40:00 2021 , end time = Wed Jun  2 09:26:00 2021
# Worker 9 assigned to task 20 sku AA0038 Cost = 45                         start time = Wed Jun  2 08:50:00 2021 , end time = Wed Jun  2 09:35:00 2021
# Worker 10 assigned to task 21 sku AA0039 Cost = 47                         start time = Wed Jun  2 08:45:00 2021 , end time = Wed Jun  2 09:32:00 2021
# Worker 11 assigned to task 22 sku AA0041 Cost = 43                         start time = Wed Jun  2 08:37:00 2021 , end time = Wed Jun  2 09:20:00 2021
# Worker 12 assigned to task 23 sku AA0042 Cost = 41                         start time = Wed Jun  2 08:41:00 2021 , end time = Wed Jun  2 09:22:00 2021
# total tasks completed =  24 remaining task =  85
#
# Worker 1 assigned to task 24 sku AA0043 Cost = 40                         start time = Wed Jun  2 09:22:00 2021 , end time = Wed Jun  2 10:02:00 2021
# Worker 2 assigned to task 25 sku AA0046 Cost = 51                         start time = Wed Jun  2 09:28:00 2021 , end time = Wed Jun  2 10:19:00 2021
# Worker 3 assigned to task 26 sku AA0047 Cost = 53                         start time = Wed Jun  2 09:30:00 2021 , end time = Wed Jun  2 10:23:00 2021
# Worker 4 assigned to task 27 sku AA0049 Cost = 43                         start time = Wed Jun  2 09:23:00 2021 , end time = Wed Jun  2 10:06:00 2021
# Worker 5 assigned to task 28 sku AA0050 Cost = 45                         start time = Wed Jun  2 09:25:00 2021 , end time = Wed Jun  2 10:10:00 2021
# Worker 6 assigned to task 29 sku AA0051 Cost = 46                         start time = Wed Jun  2 09:23:00 2021 , end time = Wed Jun  2 10:09:00 2021
# Worker 7 assigned to task 30 sku AA0053 Cost = 39                         start time = Wed Jun  2 09:24:00 2021 , end time = Wed Jun  2 10:03:00 2021
# Worker 8 assigned to task 31 sku AA0054 Cost = 46                         start time = Wed Jun  2 09:26:00 2021 , end time = Wed Jun  2 10:12:00 2021
# Worker 9 assigned to task 32 sku AA0056 Cost = 43                         start time = Wed Jun  2 09:35:00 2021 , end time = Wed Jun  2 10:18:00 2021
# Worker 10 assigned to task 33 sku AA0057 Cost = 42                         start time = Wed Jun  2 09:32:00 2021 , end time = Wed Jun  2 10:14:00 2021
# Worker 11 assigned to task 34 sku AA0058 Cost = 43                         start time = Wed Jun  2 09:20:00 2021 , end time = Wed Jun  2 10:03:00 2021
# Worker 12 assigned to task 35 sku AA0059 Cost = 59                         start time = Wed Jun  2 09:22:00 2021 , end time = Wed Jun  2 10:21:00 2021
# total tasks completed =  36 remaining task =  73
#
# Worker 1 assigned to task 36 sku AA0064 Cost = 36                         start time = Wed Jun  2 10:02:00 2021 , end time = Wed Jun  2 10:38:00 2021
# Worker 2 assigned to task 37 sku AA0065 Cost = 38                         start time = Wed Jun  2 10:19:00 2021 , end time = Wed Jun  2 10:57:00 2021
# Worker 3 assigned to task 38 sku AA0069 Cost = 55                         start time = Wed Jun  2 10:23:00 2021 , end time = Wed Jun  2 11:18:00 2021
# Worker 4 assigned to task 39 sku AA0071 Cost = 44                         start time = Wed Jun  2 10:06:00 2021 , end time = Wed Jun  2 10:50:00 2021
# Worker 5 assigned to task 40 sku AA0073 Cost = 48                         start time = Wed Jun  2 10:10:00 2021 , end time = Wed Jun  2 10:58:00 2021
# Worker 6 assigned to task 41 sku AA0075 Cost = 43                         start time = Wed Jun  2 10:09:00 2021 , end time = Wed Jun  2 10:52:00 2021
# Worker 7 assigned to task 42 sku AA0078 Cost = 43                         start time = Wed Jun  2 10:03:00 2021 , end time = Wed Jun  2 10:46:00 2021
# Worker 8 assigned to task 43 sku AA0079 Cost = 47                         start time = Wed Jun  2 10:12:00 2021 , end time = Wed Jun  2 10:59:00 2021
# Worker 9 assigned to task 44 sku AA0080 Cost = 52                         start time = Wed Jun  2 10:18:00 2021 , end time = Wed Jun  2 11:10:00 2021
# Worker 10 assigned to task 45 sku AA0081 Cost = 37                         start time = Wed Jun  2 10:14:00 2021 , end time = Wed Jun  2 10:51:00 2021
# Worker 11 assigned to task 46 sku AA0083 Cost = 43                         start time = Wed Jun  2 10:03:00 2021 , end time = Wed Jun  2 10:46:00 2021
# Worker 12 assigned to task 47 sku AA0088 Cost = 49                         start time = Wed Jun  2 10:21:00 2021 , end time = Wed Jun  2 11:10:00 2021
# total tasks completed =  48 remaining task =  61
#
# Worker 1 assigned to task 48 sku AA0091 Cost = 50                         start time = Wed Jun  2 10:38:00 2021 , end time = Wed Jun  2 11:28:00 2021
# Worker 2 assigned to task 49 sku AA0094 Cost = 48                         start time = Wed Jun  2 10:57:00 2021 , end time = Wed Jun  2 11:45:00 2021
# Worker 3 assigned to task 50 sku AA0096 Cost = 45                         start time = Wed Jun  2 11:18:00 2021 , end time = Wed Jun  2 12:03:00 2021
# Worker 4 assigned to task 51 sku AA0097 Cost = 40                         start time = Wed Jun  2 10:50:00 2021 , end time = Wed Jun  2 11:30:00 2021
# Worker 5 assigned to task 52 sku AA0098 Cost = 30                         start time = Wed Jun  2 10:58:00 2021 , end time = Wed Jun  2 11:28:00 2021
# Worker 6 assigned to task 53 sku AA0100 Cost = 40                         start time = Wed Jun  2 10:52:00 2021 , end time = Wed Jun  2 11:32:00 2021
# Worker 7 assigned to task 54 sku AA0101 Cost = 54                         start time = Wed Jun  2 10:46:00 2021 , end time = Wed Jun  2 11:40:00 2021
# Worker 8 assigned to task 55 sku AA0103 Cost = 51                         start time = Wed Jun  2 10:59:00 2021 , end time = Wed Jun  2 11:50:00 2021
# Worker 9 assigned to task 56 sku AA0105 Cost = 45                         start time = Wed Jun  2 11:10:00 2021 , end time = Wed Jun  2 11:55:00 2021
# Worker 10 assigned to task 57 sku AA0107 Cost = 45                         start time = Wed Jun  2 10:51:00 2021 , end time = Wed Jun  2 11:36:00 2021
# Worker 11 assigned to task 58 sku AA0108 Cost = 48                         start time = Wed Jun  2 10:46:00 2021 , end time = Wed Jun  2 11:34:00 2021
# Worker 12 assigned to task 59 sku AA0109 Cost = 49                         start time = Wed Jun  2 11:10:00 2021 , end time = Wed Jun  2 11:59:00 2021
# total tasks completed =  60 remaining task =  49
#
# Worker 1 assigned to task 60 sku AA0110 Cost = 41                         start time = Wed Jun  2 11:28:00 2021 , end time = Wed Jun  2 12:09:00 2021
# Worker 2 assigned to task 61 sku AA0111 Cost = 40                         start time = Wed Jun  2 11:45:00 2021 , end time = Wed Jun  2 12:25:00 2021
# Worker 3 assigned to task 62 sku AA0113 Cost = 36                         start time = Wed Jun  2 12:03:00 2021 , end time = Wed Jun  2 12:39:00 2021
# Worker 4 assigned to task 63 sku AA0114 Cost = 44                         start time = Wed Jun  2 11:30:00 2021 , end time = Wed Jun  2 12:14:00 2021
# Worker 5 assigned to task 64 sku AA0116 Cost = 38                         start time = Wed Jun  2 11:28:00 2021 , end time = Wed Jun  2 12:06:00 2021
# Worker 6 assigned to task 65 sku AA0118 Cost = 41                         start time = Wed Jun  2 11:32:00 2021 , end time = Wed Jun  2 12:13:00 2021
# Worker 7 assigned to task 66 sku AA0120 Cost = 36                         start time = Wed Jun  2 11:40:00 2021 , end time = Wed Jun  2 12:16:00 2021
# Worker 8 assigned to task 67 sku AA0122 Cost = 36                         start time = Wed Jun  2 11:50:00 2021 , end time = Wed Jun  2 12:26:00 2021
# Worker 9 assigned to task 68 sku AA0123 Cost = 45                         start time = Wed Jun  2 11:55:00 2021 , end time = Wed Jun  2 12:40:00 2021
# Worker 10 assigned to task 69 sku AA0124 Cost = 38                         start time = Wed Jun  2 11:36:00 2021 , end time = Wed Jun  2 12:14:00 2021
# Worker 11 assigned to task 70 sku AA0125 Cost = 43                         start time = Wed Jun  2 11:34:00 2021 , end time = Wed Jun  2 12:17:00 2021
# Worker 12 assigned to task 71 sku AA0126 Cost = 42                         start time = Wed Jun  2 11:59:00 2021 , end time = Wed Jun  2 12:41:00 2021
# total tasks completed =  72 remaining task =  37
#
# Worker 1 assigned to task 72 sku AA0127 Cost = 39                         start time = Wed Jun  2 12:09:00 2021 , end time = Wed Jun  2 12:48:00 2021
# Worker 2 assigned to task 73 sku AA0128 Cost = 40                         start time = Wed Jun  2 12:25:00 2021 , end time = Wed Jun  2 13:05:00 2021
# Worker 3 assigned to task 74 sku AA0129 Cost = 54                         start time = Wed Jun  2 12:39:00 2021 , end time = Wed Jun  2 13:33:00 2021
# Worker 4 assigned to task 75 sku AA0130 Cost = 37                         start time = Wed Jun  2 12:14:00 2021 , end time = Wed Jun  2 12:51:00 2021
# Worker 5 assigned to task 76 sku AA0132 Cost = 47                         start time = Wed Jun  2 12:06:00 2021 , end time = Wed Jun  2 12:53:00 2021
# Worker 6 assigned to task 77 sku AA0137 Cost = 42                         start time = Wed Jun  2 12:13:00 2021 , end time = Wed Jun  2 12:55:00 2021
# Worker 7 assigned to task 78 sku AA0138 Cost = 43                         start time = Wed Jun  2 12:16:00 2021 , end time = Wed Jun  2 12:59:00 2021
# Worker 8 assigned to task 79 sku AA0139 Cost = 45                         start time = Wed Jun  2 12:26:00 2021 , end time = Wed Jun  2 13:11:00 2021
# Worker 9 assigned to task 80 sku AA0146 Cost = 45                         start time = Wed Jun  2 12:40:00 2021 , end time = Wed Jun  2 13:25:00 2021
# Worker 10 assigned to task 81 sku AA0149 Cost = 45                         start time = Wed Jun  2 12:14:00 2021 , end time = Wed Jun  2 12:59:00 2021
# Worker 11 assigned to task 82 sku AA0150 Cost = 40                         start time = Wed Jun  2 12:17:00 2021 , end time = Wed Jun  2 12:57:00 2021
# Worker 12 assigned to task 83 sku AA0152 Cost = 44                         start time = Wed Jun  2 12:41:00 2021 , end time = Wed Jun  2 13:25:00 2021
# total tasks completed =  84 remaining task =  25
#
# Worker 1 assigned to task 84 sku AA0153 Cost = 38                         start time = Wed Jun  2 12:48:00 2021 , end time = Wed Jun  2 13:26:00 2021
# Worker 2 assigned to task 85 sku AA0154 Cost = 47                         start time = Wed Jun  2 13:05:00 2021 , end time = Wed Jun  2 13:52:00 2021
# Worker 3 assigned to task 86 sku AA0156 Cost = 45                         start time = Wed Jun  2 13:33:00 2021 , end time = Wed Jun  2 14:18:00 2021
# Worker 4 assigned to task 87 sku AA0157 Cost = 51                         start time = Wed Jun  2 12:51:00 2021 , end time = Wed Jun  2 13:42:00 2021
# Worker 5 assigned to task 88 sku AA0158 Cost = 41                         start time = Wed Jun  2 12:53:00 2021 , end time = Wed Jun  2 13:34:00 2021
# Worker 6 assigned to task 89 sku AA0159 Cost = 37                         start time = Wed Jun  2 12:55:00 2021 , end time = Wed Jun  2 13:32:00 2021
# Worker 7 assigned to task 90 sku AA0164 Cost = 32                         start time = Wed Jun  2 12:59:00 2021 , end time = Wed Jun  2 13:31:00 2021
# Worker 8 assigned to task 91 sku AA0167 Cost = 47                         start time = Wed Jun  2 13:11:00 2021 , end time = Wed Jun  2 13:58:00 2021
# Worker 9 assigned to task 92 sku AA0168 Cost = 44                         start time = Wed Jun  2 13:25:00 2021 , end time = Wed Jun  2 14:09:00 2021
# Worker 10 assigned to task 93 sku AA0172 Cost = 43                         start time = Wed Jun  2 12:59:00 2021 , end time = Wed Jun  2 13:42:00 2021
# Worker 11 assigned to task 94 sku AA0173 Cost = 39                         start time = Wed Jun  2 12:57:00 2021 , end time = Wed Jun  2 13:36:00 2021
# Worker 12 assigned to task 95 sku AA0174 Cost = 45                         start time = Wed Jun  2 13:25:00 2021 , end time = Wed Jun  2 14:10:00 2021
# total tasks completed =  96 remaining task =  13
#
# Worker 1 assigned to task 96 sku AA0180 Cost = 43                         start time = Wed Jun  2 13:26:00 2021 , end time = Wed Jun  2 14:09:00 2021
# Worker 2 assigned to task 97 sku AA0181 Cost = 44                         start time = Wed Jun  2 13:52:00 2021 , end time = Wed Jun  2 14:36:00 2021
# Worker 3 assigned to task 98 sku AA0182 Cost = 43                         start time = Wed Jun  2 14:18:00 2021 , end time = Wed Jun  2 15:01:00 2021
# Worker 4 assigned to task 99 sku AA0183 Cost = 46                         start time = Wed Jun  2 13:42:00 2021 , end time = Wed Jun  2 14:28:00 2021
# Worker 5 assigned to task 100 sku AA0184 Cost = 42                         start time = Wed Jun  2 13:34:00 2021 , end time = Wed Jun  2 14:16:00 2021
# Worker 6 assigned to task 101 sku AA0185 Cost = 40                         start time = Wed Jun  2 13:32:00 2021 , end time = Wed Jun  2 14:12:00 2021
# Worker 7 assigned to task 102 sku AA0187 Cost = 39                         start time = Wed Jun  2 13:31:00 2021 , end time = Wed Jun  2 14:10:00 2021
# Worker 8 assigned to task 103 sku AA0191 Cost = 44                         start time = Wed Jun  2 13:58:00 2021 , end time = Wed Jun  2 14:42:00 2021
# Worker 9 assigned to task 104 sku AA0192 Cost = 41                         start time = Wed Jun  2 14:09:00 2021 , end time = Wed Jun  2 14:50:00 2021
# Worker 10 assigned to task 105 sku AA0195 Cost = 55                         start time = Wed Jun  2 13:42:00 2021 , end time = Wed Jun  2 14:37:00 2021
# Worker 11 assigned to task 106 sku AA0197 Cost = 32                         start time = Wed Jun  2 13:36:00 2021 , end time = Wed Jun  2 14:08:00 2021
# Worker 12 assigned to task 107 sku AA0198 Cost = 41                         start time = Wed Jun  2 14:10:00 2021 , end time = Wed Jun  2 14:51:00 2021
# total tasks completed =  108 remaining task =  1
#
# Worker 1 assigned to task 108 sku AA0199 Cost = 40                         start time = Wed Jun  2 14:09:00 2021 end time = Wed Jun  2 14:49:00 2021
# total tasks completed =  109 remaining task =  0
#
# Worker 1 assigned to task 0 sku AA0001 Cost = 48                         start time = Thu Jun  3 08:00:00 2021 , end time = Thu Jun  3 08:48:00 2021
# Worker 2 assigned to task 1 sku AA0002 Cost = 47                         start time = Thu Jun  3 08:00:00 2021 , end time = Thu Jun  3 08:47:00 2021
# Worker 3 assigned to task 2 sku AA0003 Cost = 38                         start time = Thu Jun  3 08:00:00 2021 , end time = Thu Jun  3 08:38:00 2021
# Worker 4 assigned to task 3 sku AA0008 Cost = 45                         start time = Thu Jun  3 08:00:00 2021 , end time = Thu Jun  3 08:45:00 2021
# Worker 5 assigned to task 4 sku AA0011 Cost = 40                         start time = Thu Jun  3 08:00:00 2021 , end time = Thu Jun  3 08:40:00 2021
# Worker 6 assigned to task 5 sku AA0012 Cost = 40                         start time = Thu Jun  3 08:00:00 2021 , end time = Thu Jun  3 08:40:00 2021
# Worker 7 assigned to task 6 sku AA0013 Cost = 41                         start time = Thu Jun  3 08:00:00 2021 , end time = Thu Jun  3 08:41:00 2021
# Worker 8 assigned to task 7 sku AA0016 Cost = 41                         start time = Thu Jun  3 08:00:00 2021 , end time = Thu Jun  3 08:41:00 2021
# Worker 9 assigned to task 8 sku AA0017 Cost = 42                         start time = Thu Jun  3 08:00:00 2021 , end time = Thu Jun  3 08:42:00 2021
# Worker 10 assigned to task 9 sku AA0021 Cost = 37                         start time = Thu Jun  3 08:00:00 2021 , end time = Thu Jun  3 08:37:00 2021
# Worker 11 assigned to task 10 sku AA0023 Cost = 47                         start time = Thu Jun  3 08:00:00 2021 , end time = Thu Jun  3 08:47:00 2021
# Worker 12 assigned to task 11 sku AA0030 Cost = 44                         start time = Thu Jun  3 08:00:00 2021 , end time = Thu Jun  3 08:44:00 2021
# total tasks completed =  12 remaining task =  67
#
# Worker 1 assigned to task 12 sku AA0031 Cost = 39                         start time = Thu Jun  3 08:48:00 2021 , end time = Thu Jun  3 09:27:00 2021
# Worker 2 assigned to task 13 sku AA0033 Cost = 42                         start time = Thu Jun  3 08:47:00 2021 , end time = Thu Jun  3 09:29:00 2021
# Worker 3 assigned to task 14 sku AA0035 Cost = 41                         start time = Thu Jun  3 08:38:00 2021 , end time = Thu Jun  3 09:19:00 2021
# Worker 4 assigned to task 15 sku AA0037 Cost = 40                         start time = Thu Jun  3 08:45:00 2021 , end time = Thu Jun  3 09:25:00 2021
# Worker 5 assigned to task 16 sku AA0040 Cost = 40                         start time = Thu Jun  3 08:40:00 2021 , end time = Thu Jun  3 09:20:00 2021
# Worker 6 assigned to task 17 sku AA0043 Cost = 43                         start time = Thu Jun  3 08:40:00 2021 , end time = Thu Jun  3 09:23:00 2021
# Worker 7 assigned to task 18 sku AA0044 Cost = 46                         start time = Thu Jun  3 08:41:00 2021 , end time = Thu Jun  3 09:27:00 2021
# Worker 8 assigned to task 19 sku AA0047 Cost = 55                         start time = Thu Jun  3 08:41:00 2021 , end time = Thu Jun  3 09:36:00 2021
# Worker 9 assigned to task 20 sku AA0048 Cost = 47                         start time = Thu Jun  3 08:42:00 2021 , end time = Thu Jun  3 09:29:00 2021
# Worker 10 assigned to task 21 sku AA0049 Cost = 46                         start time = Thu Jun  3 08:37:00 2021 , end time = Thu Jun  3 09:23:00 2021
# Worker 11 assigned to task 22 sku AA0058 Cost = 42                         start time = Thu Jun  3 08:47:00 2021 , end time = Thu Jun  3 09:29:00 2021
# Worker 12 assigned to task 23 sku AA0059 Cost = 46                         start time = Thu Jun  3 08:44:00 2021 , end time = Thu Jun  3 09:30:00 2021
# total tasks completed =  24 remaining task =  55
#
# Worker 1 assigned to task 24 sku AA0061 Cost = 30                         start time = Thu Jun  3 09:27:00 2021 , end time = Thu Jun  3 09:57:00 2021
# Worker 2 assigned to task 25 sku AA0062 Cost = 40                         start time = Thu Jun  3 09:29:00 2021 , end time = Thu Jun  3 10:09:00 2021
# Worker 3 assigned to task 26 sku AA0064 Cost = 37                         start time = Thu Jun  3 09:19:00 2021 , end time = Thu Jun  3 09:56:00 2021
# Worker 4 assigned to task 27 sku AA0069 Cost = 46                         start time = Thu Jun  3 09:25:00 2021 , end time = Thu Jun  3 10:11:00 2021
# Worker 5 assigned to task 28 sku AA0072 Cost = 48                         start time = Thu Jun  3 09:20:00 2021 , end time = Thu Jun  3 10:08:00 2021
# Worker 6 assigned to task 29 sku AA0075 Cost = 54                         start time = Thu Jun  3 09:23:00 2021 , end time = Thu Jun  3 10:17:00 2021
# Worker 7 assigned to task 30 sku AA0077 Cost = 40                         start time = Thu Jun  3 09:27:00 2021 , end time = Thu Jun  3 10:07:00 2021
# Worker 8 assigned to task 31 sku AA0079 Cost = 51                         start time = Thu Jun  3 09:36:00 2021 , end time = Thu Jun  3 10:27:00 2021
# Worker 9 assigned to task 32 sku AA0080 Cost = 53                         start time = Thu Jun  3 09:29:00 2021 , end time = Thu Jun  3 10:22:00 2021
# Worker 10 assigned to task 33 sku AA0081 Cost = 40                         start time = Thu Jun  3 09:23:00 2021 , end time = Thu Jun  3 10:03:00 2021
# Worker 11 assigned to task 34 sku AA0082 Cost = 44                         start time = Thu Jun  3 09:29:00 2021 , end time = Thu Jun  3 10:13:00 2021
# Worker 12 assigned to task 35 sku AA0084 Cost = 50                         start time = Thu Jun  3 09:30:00 2021 , end time = Thu Jun  3 10:20:00 2021
# total tasks completed =  36 remaining task =  43
#
# Worker 1 assigned to task 36 sku AA0086 Cost = 45                         start time = Thu Jun  3 09:57:00 2021 , end time = Thu Jun  3 10:42:00 2021
# Worker 2 assigned to task 37 sku AA0088 Cost = 41                         start time = Thu Jun  3 10:09:00 2021 , end time = Thu Jun  3 10:50:00 2021
# Worker 3 assigned to task 38 sku AA0089 Cost = 43                         start time = Thu Jun  3 09:56:00 2021 , end time = Thu Jun  3 10:39:00 2021
# Worker 4 assigned to task 39 sku AA0090 Cost = 41                         start time = Thu Jun  3 10:11:00 2021 , end time = Thu Jun  3 10:52:00 2021
# Worker 5 assigned to task 40 sku AA0094 Cost = 39                         start time = Thu Jun  3 10:08:00 2021 , end time = Thu Jun  3 10:47:00 2021
# Worker 6 assigned to task 41 sku AA0101 Cost = 43                         start time = Thu Jun  3 10:17:00 2021 , end time = Thu Jun  3 11:00:00 2021
# Worker 7 assigned to task 42 sku AA0102 Cost = 44                         start time = Thu Jun  3 10:07:00 2021 , end time = Thu Jun  3 10:51:00 2021
# Worker 8 assigned to task 43 sku AA0106 Cost = 38                         start time = Thu Jun  3 10:27:00 2021 , end time = Thu Jun  3 11:05:00 2021
# Worker 9 assigned to task 44 sku AA0108 Cost = 37                         start time = Thu Jun  3 10:22:00 2021 , end time = Thu Jun  3 10:59:00 2021
# Worker 10 assigned to task 45 sku AA0109 Cost = 43                         start time = Thu Jun  3 10:03:00 2021 , end time = Thu Jun  3 10:46:00 2021
# Worker 11 assigned to task 46 sku AA0110 Cost = 41                         start time = Thu Jun  3 10:13:00 2021 , end time = Thu Jun  3 10:54:00 2021
# Worker 12 assigned to task 47 sku AA0116 Cost = 46                         start time = Thu Jun  3 10:20:00 2021 , end time = Thu Jun  3 11:06:00 2021
# total tasks completed =  48 remaining task =  31
#
# Worker 1 assigned to task 48 sku AA0117 Cost = 40                         start time = Thu Jun  3 10:42:00 2021 , end time = Thu Jun  3 11:22:00 2021
# Worker 2 assigned to task 49 sku AA0118 Cost = 43                         start time = Thu Jun  3 10:50:00 2021 , end time = Thu Jun  3 11:33:00 2021
# Worker 3 assigned to task 50 sku AA0120 Cost = 42                         start time = Thu Jun  3 10:39:00 2021 , end time = Thu Jun  3 11:21:00 2021
# Worker 4 assigned to task 51 sku AA0121 Cost = 44                         start time = Thu Jun  3 10:52:00 2021 , end time = Thu Jun  3 11:36:00 2021
# Worker 5 assigned to task 52 sku AA0123 Cost = 53                         start time = Thu Jun  3 10:47:00 2021 , end time = Thu Jun  3 11:40:00 2021
# Worker 6 assigned to task 53 sku AA0131 Cost = 45                         start time = Thu Jun  3 11:00:00 2021 , end time = Thu Jun  3 11:45:00 2021
# Worker 7 assigned to task 54 sku AA0132 Cost = 44                         start time = Thu Jun  3 10:51:00 2021 , end time = Thu Jun  3 11:35:00 2021
# Worker 8 assigned to task 55 sku AA0133 Cost = 40                         start time = Thu Jun  3 11:05:00 2021 , end time = Thu Jun  3 11:45:00 2021
# Worker 9 assigned to task 56 sku AA0136 Cost = 42                         start time = Thu Jun  3 10:59:00 2021 , end time = Thu Jun  3 11:41:00 2021
# Worker 10 assigned to task 57 sku AA0137 Cost = 46                         start time = Thu Jun  3 10:46:00 2021 , end time = Thu Jun  3 11:32:00 2021
# Worker 11 assigned to task 58 sku AA0138 Cost = 41                         start time = Thu Jun  3 10:54:00 2021 , end time = Thu Jun  3 11:35:00 2021
# Worker 12 assigned to task 59 sku AA0143 Cost = 39                         start time = Thu Jun  3 11:06:00 2021 , end time = Thu Jun  3 11:45:00 2021
# total tasks completed =  60 remaining task =  19
#
# Worker 1 assigned to task 60 sku AA0145 Cost = 52                         start time = Thu Jun  3 11:22:00 2021 , end time = Thu Jun  3 12:14:00 2021
# Worker 2 assigned to task 61 sku AA0146 Cost = 43                         start time = Thu Jun  3 11:33:00 2021 , end time = Thu Jun  3 12:16:00 2021
# Worker 3 assigned to task 62 sku AA0151 Cost = 42                         start time = Thu Jun  3 11:21:00 2021 , end time = Thu Jun  3 12:03:00 2021
# Worker 4 assigned to task 63 sku AA0155 Cost = 39                         start time = Thu Jun  3 11:36:00 2021 , end time = Thu Jun  3 12:15:00 2021
# Worker 5 assigned to task 64 sku AA0156 Cost = 39                         start time = Thu Jun  3 11:40:00 2021 , end time = Thu Jun  3 12:19:00 2021
# Worker 6 assigned to task 65 sku AA0157 Cost = 47                         start time = Thu Jun  3 11:45:00 2021 , end time = Thu Jun  3 12:32:00 2021
# Worker 7 assigned to task 66 sku AA0162 Cost = 39                         start time = Thu Jun  3 11:35:00 2021 , end time = Thu Jun  3 12:14:00 2021
# Worker 8 assigned to task 67 sku AA0165 Cost = 41                         start time = Thu Jun  3 11:45:00 2021 , end time = Thu Jun  3 12:26:00 2021
# Worker 9 assigned to task 68 sku AA0167 Cost = 44                         start time = Thu Jun  3 11:41:00 2021 , end time = Thu Jun  3 12:25:00 2021
# Worker 10 assigned to task 69 sku AA0176 Cost = 37                         start time = Thu Jun  3 11:32:00 2021 , end time = Thu Jun  3 12:09:00 2021
# Worker 11 assigned to task 70 sku AA0179 Cost = 45                         start time = Thu Jun  3 11:35:00 2021 , end time = Thu Jun  3 12:20:00 2021
# Worker 12 assigned to task 71 sku AA0183 Cost = 40                         start time = Thu Jun  3 11:45:00 2021 , end time = Thu Jun  3 12:25:00 2021
# total tasks completed =  72 remaining task =  7
#
# Worker 1 assigned to task 72 sku AA0185 Cost = 44                         start time = Thu Jun  3 12:14:00 2021 end time = Thu Jun  3 12:58:00 2021
# Worker 2 assigned to task 73 sku AA0187 Cost = 36                         start time = Thu Jun  3 12:16:00 2021 end time = Thu Jun  3 12:52:00 2021
# Worker 3 assigned to task 74 sku AA0190 Cost = 39                         start time = Thu Jun  3 12:03:00 2021 end time = Thu Jun  3 12:42:00 2021
# Worker 4 assigned to task 75 sku AA0192 Cost = 41                         start time = Thu Jun  3 12:15:00 2021 end time = Thu Jun  3 12:56:00 2021
# Worker 5 assigned to task 76 sku AA0195 Cost = 48                         start time = Thu Jun  3 12:19:00 2021 end time = Thu Jun  3 13:07:00 2021
# Worker 6 assigned to task 77 sku AA0196 Cost = 41                         start time = Thu Jun  3 12:32:00 2021 end time = Thu Jun  3 13:13:00 2021
# Worker 7 assigned to task 78 sku AA0198 Cost = 42                         start time = Thu Jun  3 12:14:00 2021 end time = Thu Jun  3 12:56:00 2021
# total tasks completed =  79 remaining task =  0
#
# Worker 1 assigned to task 0 sku AA0005 Cost = 43                         start time = Fri Jun  4 08:00:00 2021 , end time = Fri Jun  4 08:43:00 2021
# Worker 2 assigned to task 1 sku AA0007 Cost = 48                         start time = Fri Jun  4 08:00:00 2021 , end time = Fri Jun  4 08:48:00 2021
# Worker 3 assigned to task 2 sku AA0008 Cost = 48                         start time = Fri Jun  4 08:00:00 2021 , end time = Fri Jun  4 08:48:00 2021
# Worker 4 assigned to task 3 sku AA0009 Cost = 42                         start time = Fri Jun  4 08:00:00 2021 , end time = Fri Jun  4 08:42:00 2021
# Worker 5 assigned to task 4 sku AA0011 Cost = 34                         start time = Fri Jun  4 08:00:00 2021 , end time = Fri Jun  4 08:34:00 2021
# Worker 6 assigned to task 5 sku AA0017 Cost = 53                         start time = Fri Jun  4 08:00:00 2021 , end time = Fri Jun  4 08:53:00 2021
# Worker 7 assigned to task 6 sku AA0018 Cost = 41                         start time = Fri Jun  4 08:00:00 2021 , end time = Fri Jun  4 08:41:00 2021
# Worker 8 assigned to task 7 sku AA0021 Cost = 41                         start time = Fri Jun  4 08:00:00 2021 , end time = Fri Jun  4 08:41:00 2021
# Worker 9 assigned to task 8 sku AA0022 Cost = 44                         start time = Fri Jun  4 08:00:00 2021 , end time = Fri Jun  4 08:44:00 2021
# Worker 10 assigned to task 9 sku AA0026 Cost = 40                         start time = Fri Jun  4 08:00:00 2021 , end time = Fri Jun  4 08:40:00 2021
# Worker 11 assigned to task 10 sku AA0028 Cost = 59                         start time = Fri Jun  4 08:00:00 2021 , end time = Fri Jun  4 08:59:00 2021
# Worker 12 assigned to task 11 sku AA0029 Cost = 41                         start time = Fri Jun  4 08:00:00 2021 , end time = Fri Jun  4 08:41:00 2021
# total tasks completed =  12 remaining task =  72
#
# Worker 1 assigned to task 12 sku AA0031 Cost = 47                         start time = Fri Jun  4 08:43:00 2021 , end time = Fri Jun  4 09:30:00 2021
# Worker 2 assigned to task 13 sku AA0033 Cost = 39                         start time = Fri Jun  4 08:48:00 2021 , end time = Fri Jun  4 09:27:00 2021
# Worker 3 assigned to task 14 sku AA0039 Cost = 41                         start time = Fri Jun  4 08:48:00 2021 , end time = Fri Jun  4 09:29:00 2021
# Worker 4 assigned to task 15 sku AA0041 Cost = 55                         start time = Fri Jun  4 08:42:00 2021 , end time = Fri Jun  4 09:37:00 2021
# Worker 5 assigned to task 16 sku AA0044 Cost = 43                         start time = Fri Jun  4 08:34:00 2021 , end time = Fri Jun  4 09:17:00 2021
# Worker 6 assigned to task 17 sku AA0048 Cost = 40                         start time = Fri Jun  4 08:53:00 2021 , end time = Fri Jun  4 09:33:00 2021
# Worker 7 assigned to task 18 sku AA0050 Cost = 41                         start time = Fri Jun  4 08:41:00 2021 , end time = Fri Jun  4 09:22:00 2021
# Worker 8 assigned to task 19 sku AA0054 Cost = 51                         start time = Fri Jun  4 08:41:00 2021 , end time = Fri Jun  4 09:32:00 2021
# Worker 9 assigned to task 20 sku AA0055 Cost = 46                         start time = Fri Jun  4 08:44:00 2021 , end time = Fri Jun  4 09:30:00 2021
# Worker 10 assigned to task 21 sku AA0058 Cost = 42                         start time = Fri Jun  4 08:40:00 2021 , end time = Fri Jun  4 09:22:00 2021
# Worker 11 assigned to task 22 sku AA0059 Cost = 42                         start time = Fri Jun  4 08:59:00 2021 , end time = Fri Jun  4 09:41:00 2021
# Worker 12 assigned to task 23 sku AA0060 Cost = 40                         start time = Fri Jun  4 08:41:00 2021 , end time = Fri Jun  4 09:21:00 2021
# total tasks completed =  24 remaining task =  60
#
# Worker 1 assigned to task 24 sku AA0061 Cost = 34                         start time = Fri Jun  4 09:30:00 2021 , end time = Fri Jun  4 10:04:00 2021
# Worker 2 assigned to task 25 sku AA0063 Cost = 37                         start time = Fri Jun  4 09:27:00 2021 , end time = Fri Jun  4 10:04:00 2021
# Worker 3 assigned to task 26 sku AA0064 Cost = 44                         start time = Fri Jun  4 09:29:00 2021 , end time = Fri Jun  4 10:13:00 2021
# Worker 4 assigned to task 27 sku AA0066 Cost = 46                         start time = Fri Jun  4 09:37:00 2021 , end time = Fri Jun  4 10:23:00 2021
# Worker 5 assigned to task 28 sku AA0071 Cost = 46                         start time = Fri Jun  4 09:17:00 2021 , end time = Fri Jun  4 10:03:00 2021
# Worker 6 assigned to task 29 sku AA0073 Cost = 46                         start time = Fri Jun  4 09:33:00 2021 , end time = Fri Jun  4 10:19:00 2021
# Worker 7 assigned to task 30 sku AA0074 Cost = 51                         start time = Fri Jun  4 09:22:00 2021 , end time = Fri Jun  4 10:13:00 2021
# Worker 8 assigned to task 31 sku AA0077 Cost = 45                         start time = Fri Jun  4 09:32:00 2021 , end time = Fri Jun  4 10:17:00 2021
# Worker 9 assigned to task 32 sku AA0083 Cost = 41                         start time = Fri Jun  4 09:30:00 2021 , end time = Fri Jun  4 10:11:00 2021
# Worker 10 assigned to task 33 sku AA0085 Cost = 34                         start time = Fri Jun  4 09:22:00 2021 , end time = Fri Jun  4 09:56:00 2021
# Worker 11 assigned to task 34 sku AA0086 Cost = 41                         start time = Fri Jun  4 09:41:00 2021 , end time = Fri Jun  4 10:22:00 2021
# Worker 12 assigned to task 35 sku AA0088 Cost = 51                         start time = Fri Jun  4 09:21:00 2021 , end time = Fri Jun  4 10:12:00 2021
# total tasks completed =  36 remaining task =  48
#
# Worker 1 assigned to task 36 sku AA0090 Cost = 51                         start time = Fri Jun  4 10:04:00 2021 , end time = Fri Jun  4 10:55:00 2021
# Worker 2 assigned to task 37 sku AA0093 Cost = 47                         start time = Fri Jun  4 10:04:00 2021 , end time = Fri Jun  4 10:51:00 2021
# Worker 3 assigned to task 38 sku AA0095 Cost = 31                         start time = Fri Jun  4 10:13:00 2021 , end time = Fri Jun  4 10:44:00 2021
# Worker 4 assigned to task 39 sku AA0099 Cost = 42                         start time = Fri Jun  4 10:23:00 2021 , end time = Fri Jun  4 11:05:00 2021
# Worker 5 assigned to task 40 sku AA0100 Cost = 37                         start time = Fri Jun  4 10:03:00 2021 , end time = Fri Jun  4 10:40:00 2021
# Worker 6 assigned to task 41 sku AA0102 Cost = 44                         start time = Fri Jun  4 10:19:00 2021 , end time = Fri Jun  4 11:03:00 2021
# Worker 7 assigned to task 42 sku AA0105 Cost = 37                         start time = Fri Jun  4 10:13:00 2021 , end time = Fri Jun  4 10:50:00 2021
# Worker 8 assigned to task 43 sku AA0117 Cost = 48                         start time = Fri Jun  4 10:17:00 2021 , end time = Fri Jun  4 11:05:00 2021
# Worker 9 assigned to task 44 sku AA0119 Cost = 40                         start time = Fri Jun  4 10:11:00 2021 , end time = Fri Jun  4 10:51:00 2021
# Worker 10 assigned to task 45 sku AA0121 Cost = 44                         start time = Fri Jun  4 09:56:00 2021 , end time = Fri Jun  4 10:40:00 2021
# Worker 11 assigned to task 46 sku AA0122 Cost = 38                         start time = Fri Jun  4 10:22:00 2021 , end time = Fri Jun  4 11:00:00 2021
# Worker 12 assigned to task 47 sku AA0123 Cost = 43                         start time = Fri Jun  4 10:12:00 2021 , end time = Fri Jun  4 10:55:00 2021
# total tasks completed =  48 remaining task =  36
#
# Worker 1 assigned to task 48 sku AA0125 Cost = 50                         start time = Fri Jun  4 10:55:00 2021 , end time = Fri Jun  4 11:45:00 2021
# Worker 2 assigned to task 49 sku AA0126 Cost = 53                         start time = Fri Jun  4 10:51:00 2021 , end time = Fri Jun  4 11:44:00 2021
# Worker 3 assigned to task 50 sku AA0127 Cost = 37                         start time = Fri Jun  4 10:44:00 2021 , end time = Fri Jun  4 11:21:00 2021
# Worker 4 assigned to task 51 sku AA0134 Cost = 40                         start time = Fri Jun  4 11:05:00 2021 , end time = Fri Jun  4 11:45:00 2021
# Worker 5 assigned to task 52 sku AA0137 Cost = 58                         start time = Fri Jun  4 10:40:00 2021 , end time = Fri Jun  4 11:38:00 2021
# Worker 6 assigned to task 53 sku AA0138 Cost = 45                         start time = Fri Jun  4 11:03:00 2021 , end time = Fri Jun  4 11:48:00 2021
# Worker 7 assigned to task 54 sku AA0139 Cost = 47                         start time = Fri Jun  4 10:50:00 2021 , end time = Fri Jun  4 11:37:00 2021
# Worker 8 assigned to task 55 sku AA0141 Cost = 45                         start time = Fri Jun  4 11:05:00 2021 , end time = Fri Jun  4 11:50:00 2021
# Worker 9 assigned to task 56 sku AA0144 Cost = 52                         start time = Fri Jun  4 10:51:00 2021 , end time = Fri Jun  4 11:43:00 2021
# Worker 10 assigned to task 57 sku AA0149 Cost = 43                         start time = Fri Jun  4 10:40:00 2021 , end time = Fri Jun  4 11:23:00 2021
# Worker 11 assigned to task 58 sku AA0150 Cost = 42                         start time = Fri Jun  4 11:00:00 2021 , end time = Fri Jun  4 11:42:00 2021
# Worker 12 assigned to task 59 sku AA0153 Cost = 43                         start time = Fri Jun  4 10:55:00 2021 , end time = Fri Jun  4 11:38:00 2021
# total tasks completed =  60 remaining task =  24
#
# Worker 1 assigned to task 60 sku AA0156 Cost = 50                         start time = Fri Jun  4 11:45:00 2021 , end time = Fri Jun  4 12:35:00 2021
# Worker 2 assigned to task 61 sku AA0157 Cost = 39                         start time = Fri Jun  4 11:44:00 2021 , end time = Fri Jun  4 12:23:00 2021
# Worker 3 assigned to task 62 sku AA0161 Cost = 45                         start time = Fri Jun  4 11:21:00 2021 , end time = Fri Jun  4 12:06:00 2021
# Worker 4 assigned to task 63 sku AA0163 Cost = 43                         start time = Fri Jun  4 11:45:00 2021 , end time = Fri Jun  4 12:28:00 2021
# Worker 5 assigned to task 64 sku AA0168 Cost = 43                         start time = Fri Jun  4 11:38:00 2021 , end time = Fri Jun  4 12:21:00 2021
# Worker 6 assigned to task 65 sku AA0170 Cost = 37                         start time = Fri Jun  4 11:48:00 2021 , end time = Fri Jun  4 12:25:00 2021
# Worker 7 assigned to task 66 sku AA0171 Cost = 40                         start time = Fri Jun  4 11:37:00 2021 , end time = Fri Jun  4 12:17:00 2021
# Worker 8 assigned to task 67 sku AA0173 Cost = 41                         start time = Fri Jun  4 11:50:00 2021 , end time = Fri Jun  4 12:31:00 2021
# Worker 9 assigned to task 68 sku AA0177 Cost = 42                         start time = Fri Jun  4 11:43:00 2021 , end time = Fri Jun  4 12:25:00 2021
# Worker 10 assigned to task 69 sku AA0179 Cost = 45                         start time = Fri Jun  4 11:23:00 2021 , end time = Fri Jun  4 12:08:00 2021
# Worker 11 assigned to task 70 sku AA0181 Cost = 43                         start time = Fri Jun  4 11:42:00 2021 , end time = Fri Jun  4 12:25:00 2021
# Worker 12 assigned to task 71 sku AA0182 Cost = 41                         start time = Fri Jun  4 11:38:00 2021 , end time = Fri Jun  4 12:19:00 2021
# total tasks completed =  72 remaining task =  12
#
# Worker 1 assigned to task 72 sku AA0183 Cost = 40                         start time = Fri Jun  4 12:35:00 2021 end time = Fri Jun  4 13:15:00 2021
# Worker 2 assigned to task 73 sku AA0184 Cost = 41                         start time = Fri Jun  4 12:23:00 2021 end time = Fri Jun  4 13:04:00 2021
# Worker 3 assigned to task 74 sku AA0187 Cost = 52                         start time = Fri Jun  4 12:06:00 2021 end time = Fri Jun  4 12:58:00 2021
# Worker 4 assigned to task 75 sku AA0188 Cost = 43                         start time = Fri Jun  4 12:28:00 2021 end time = Fri Jun  4 13:11:00 2021
# ...
# Worker 12 assigned to task 23 sku AA0038 Cost = 46                         start time = Wed Jun 30 08:44:00 2021 , end time = Wed Jun 30 09:30:00 2021
# total tasks completed =  24 remaining task =  102
#
# Worker 1 assigned to task 24 sku AA0042 Cost = 40                         start time = Wed Jun 30 09:21:00 2021 , end time = Wed Jun 30 10:01:00 2021
# Worker 2 assigned to task 25 sku AA0043 Cost = 43                         start time = Wed Jun 30 09:29:00 2021 , end time = Wed Jun 30 10:12:00 2021
# Worker 3 assigned to task 26 sku AA0046 Cost = 41                         start time = Wed Jun 30 09:33:00 2021 , end time = Wed Jun 30 10:14:00 2021
# Worker 4 assigned to task 27 sku AA0047 Cost = 44                         start time = Wed Jun 30 09:18:00 2021 , end time = Wed Jun 30 10:02:00 2021
# Worker 5 assigned to task 28 sku AA0048 Cost = 40                         start time = Wed Jun 30 09:46:00 2021 , end time = Wed Jun 30 10:26:00 2021
# Worker 6 assigned to task 29 sku AA0051 Cost = 50                         start time = Wed Jun 30 09:38:00 2021 , end time = Wed Jun 30 10:28:00 2021
# Worker 7 assigned to task 30 sku AA0052 Cost = 44                         start time = Wed Jun 30 09:37:00 2021 , end time = Wed Jun 30 10:21:00 2021
# Worker 8 assigned to task 31 sku AA0054 Cost = 45                         start time = Wed Jun 30 09:27:00 2021 , end time = Wed Jun 30 10:12:00 2021
# Worker 9 assigned to task 32 sku AA0055 Cost = 44                         start time = Wed Jun 30 09:40:00 2021 , end time = Wed Jun 30 10:24:00 2021
# Worker 10 assigned to task 33 sku AA0056 Cost = 47                         start time = Wed Jun 30 09:28:00 2021 , end time = Wed Jun 30 10:15:00 2021
# Worker 11 assigned to task 34 sku AA0057 Cost = 40                         start time = Wed Jun 30 09:26:00 2021 , end time = Wed Jun 30 10:06:00 2021
# Worker 12 assigned to task 35 sku AA0058 Cost = 43                         start time = Wed Jun 30 09:30:00 2021 , end time = Wed Jun 30 10:13:00 2021
# total tasks completed =  36 remaining task =  90
#
# Worker 1 assigned to task 36 sku AA0059 Cost = 47                         start time = Wed Jun 30 10:01:00 2021 , end time = Wed Jun 30 10:48:00 2021
# Worker 2 assigned to task 37 sku AA0061 Cost = 54                         start time = Wed Jun 30 10:12:00 2021 , end time = Wed Jun 30 11:06:00 2021
# Worker 3 assigned to task 38 sku AA0063 Cost = 43                         start time = Wed Jun 30 10:14:00 2021 , end time = Wed Jun 30 10:57:00 2021
# Worker 4 assigned to task 39 sku AA0066 Cost = 41                         start time = Wed Jun 30 10:02:00 2021 , end time = Wed Jun 30 10:43:00 2021
# Worker 5 assigned to task 40 sku AA0067 Cost = 52                         start time = Wed Jun 30 10:26:00 2021 , end time = Wed Jun 30 11:18:00 2021
# Worker 6 assigned to task 41 sku AA0068 Cost = 51                         start time = Wed Jun 30 10:28:00 2021 , end time = Wed Jun 30 11:19:00 2021
# Worker 7 assigned to task 42 sku AA0070 Cost = 46                         start time = Wed Jun 30 10:21:00 2021 , end time = Wed Jun 30 11:07:00 2021
# Worker 8 assigned to task 43 sku AA0073 Cost = 38                         start time = Wed Jun 30 10:12:00 2021 , end time = Wed Jun 30 10:50:00 2021
# Worker 9 assigned to task 44 sku AA0074 Cost = 49                         start time = Wed Jun 30 10:24:00 2021 , end time = Wed Jun 30 11:13:00 2021
# Worker 10 assigned to task 45 sku AA0075 Cost = 46                         start time = Wed Jun 30 10:15:00 2021 , end time = Wed Jun 30 11:01:00 2021
# Worker 11 assigned to task 46 sku AA0076 Cost = 53                         start time = Wed Jun 30 10:06:00 2021 , end time = Wed Jun 30 10:59:00 2021
# Worker 12 assigned to task 47 sku AA0077 Cost = 50                         start time = Wed Jun 30 10:13:00 2021 , end time = Wed Jun 30 11:03:00 2021
# total tasks completed =  48 remaining task =  78
#
# Worker 1 assigned to task 48 sku AA0079 Cost = 50                         start time = Wed Jun 30 10:48:00 2021 , end time = Wed Jun 30 11:38:00 2021
# Worker 2 assigned to task 49 sku AA0081 Cost = 42                         start time = Wed Jun 30 11:06:00 2021 , end time = Wed Jun 30 11:48:00 2021
# Worker 3 assigned to task 50 sku AA0082 Cost = 49                         start time = Wed Jun 30 10:57:00 2021 , end time = Wed Jun 30 11:46:00 2021
# Worker 4 assigned to task 51 sku AA0083 Cost = 66                         start time = Wed Jun 30 10:43:00 2021 , end time = Wed Jun 30 11:49:00 2021
# Worker 5 assigned to task 52 sku AA0084 Cost = 41                         start time = Wed Jun 30 11:18:00 2021 , end time = Wed Jun 30 11:59:00 2021
# Worker 6 assigned to task 53 sku AA0086 Cost = 55                         start time = Wed Jun 30 11:19:00 2021 , end time = Wed Jun 30 12:14:00 2021
# Worker 7 assigned to task 54 sku AA0087 Cost = 39                         start time = Wed Jun 30 11:07:00 2021 , end time = Wed Jun 30 11:46:00 2021
# Worker 8 assigned to task 55 sku AA0089 Cost = 43                         start time = Wed Jun 30 10:50:00 2021 , end time = Wed Jun 30 11:33:00 2021
# Worker 9 assigned to task 56 sku AA0092 Cost = 41                         start time = Wed Jun 30 11:13:00 2021 , end time = Wed Jun 30 11:54:00 2021
# Worker 10 assigned to task 57 sku AA0094 Cost = 54                         start time = Wed Jun 30 11:01:00 2021 , end time = Wed Jun 30 11:55:00 2021
# Worker 11 assigned to task 58 sku AA0095 Cost = 36                         start time = Wed Jun 30 10:59:00 2021 , end time = Wed Jun 30 11:35:00 2021
# Worker 12 assigned to task 59 sku AA0098 Cost = 37                         start time = Wed Jun 30 11:03:00 2021 , end time = Wed Jun 30 11:40:00 2021
# total tasks completed =  60 remaining task =  66
#
# Worker 1 assigned to task 60 sku AA0099 Cost = 39                         start time = Wed Jun 30 11:38:00 2021 , end time = Wed Jun 30 12:17:00 2021
# Worker 2 assigned to task 61 sku AA0100 Cost = 35                         start time = Wed Jun 30 11:48:00 2021 , end time = Wed Jun 30 12:23:00 2021
# Worker 3 assigned to task 62 sku AA0101 Cost = 41                         start time = Wed Jun 30 11:46:00 2021 , end time = Wed Jun 30 12:27:00 2021
# Worker 4 assigned to task 63 sku AA0102 Cost = 38                         start time = Wed Jun 30 11:49:00 2021 , end time = Wed Jun 30 12:27:00 2021
# Worker 5 assigned to task 64 sku AA0103 Cost = 49                         start time = Wed Jun 30 11:59:00 2021 , end time = Wed Jun 30 12:48:00 2021
# Worker 6 assigned to task 65 sku AA0104 Cost = 39                         start time = Wed Jun 30 12:14:00 2021 , end time = Wed Jun 30 12:53:00 2021
# Worker 7 assigned to task 66 sku AA0105 Cost = 38                         start time = Wed Jun 30 11:46:00 2021 , end time = Wed Jun 30 12:24:00 2021
# Worker 8 assigned to task 67 sku AA0106 Cost = 47                         start time = Wed Jun 30 11:33:00 2021 , end time = Wed Jun 30 12:20:00 2021
# Worker 9 assigned to task 68 sku AA0108 Cost = 38                         start time = Wed Jun 30 11:54:00 2021 , end time = Wed Jun 30 12:32:00 2021
# Worker 10 assigned to task 69 sku AA0109 Cost = 43                         start time = Wed Jun 30 11:55:00 2021 , end time = Wed Jun 30 12:38:00 2021
# Worker 11 assigned to task 70 sku AA0110 Cost = 42                         start time = Wed Jun 30 11:35:00 2021 , end time = Wed Jun 30 12:17:00 2021
# Worker 12 assigned to task 71 sku AA0113 Cost = 48                         start time = Wed Jun 30 11:40:00 2021 , end time = Wed Jun 30 12:28:00 2021
# total tasks completed =  72 remaining task =  54
#
# Worker 1 assigned to task 72 sku AA0115 Cost = 45                         start time = Wed Jun 30 12:17:00 2021 , end time = Wed Jun 30 13:02:00 2021
# Worker 2 assigned to task 73 sku AA0116 Cost = 47                         start time = Wed Jun 30 12:23:00 2021 , end time = Wed Jun 30 13:10:00 2021
# Worker 3 assigned to task 74 sku AA0117 Cost = 51                         start time = Wed Jun 30 12:27:00 2021 , end time = Wed Jun 30 13:18:00 2021
# Worker 4 assigned to task 75 sku AA0118 Cost = 52                         start time = Wed Jun 30 12:27:00 2021 , end time = Wed Jun 30 13:19:00 2021
# Worker 5 assigned to task 76 sku AA0120 Cost = 45                         start time = Wed Jun 30 12:48:00 2021 , end time = Wed Jun 30 13:33:00 2021
# Worker 6 assigned to task 77 sku AA0121 Cost = 51                         start time = Wed Jun 30 12:53:00 2021 , end time = Wed Jun 30 13:44:00 2021
# Worker 7 assigned to task 78 sku AA0124 Cost = 58                         start time = Wed Jun 30 12:24:00 2021 , end time = Wed Jun 30 13:22:00 2021
# Worker 8 assigned to task 79 sku AA0125 Cost = 38                         start time = Wed Jun 30 12:20:00 2021 , end time = Wed Jun 30 12:58:00 2021
# Worker 9 assigned to task 80 sku AA0126 Cost = 49                         start time = Wed Jun 30 12:32:00 2021 , end time = Wed Jun 30 13:21:00 2021
# Worker 10 assigned to task 81 sku AA0128 Cost = 31                         start time = Wed Jun 30 12:38:00 2021 , end time = Wed Jun 30 13:09:00 2021
# Worker 11 assigned to task 82 sku AA0131 Cost = 38                         start time = Wed Jun 30 12:17:00 2021 , end time = Wed Jun 30 12:55:00 2021
# Worker 12 assigned to task 83 sku AA0132 Cost = 56                         start time = Wed Jun 30 12:28:00 2021 , end time = Wed Jun 30 13:24:00 2021
# total tasks completed =  84 remaining task =  42
#
# Worker 1 assigned to task 84 sku AA0133 Cost = 36                         start time = Wed Jun 30 13:02:00 2021 , end time = Wed Jun 30 13:38:00 2021
# Worker 2 assigned to task 85 sku AA0135 Cost = 47                         start time = Wed Jun 30 13:10:00 2021 , end time = Wed Jun 30 13:57:00 2021
# Worker 3 assigned to task 86 sku AA0138 Cost = 45                         start time = Wed Jun 30 13:18:00 2021 , end time = Wed Jun 30 14:03:00 2021
# Worker 4 assigned to task 87 sku AA0141 Cost = 60                         start time = Wed Jun 30 13:19:00 2021 , end time = Wed Jun 30 14:19:00 2021
# Worker 5 assigned to task 88 sku AA0142 Cost = 42                         start time = Wed Jun 30 13:33:00 2021 , end time = Wed Jun 30 14:15:00 2021
# Worker 6 assigned to task 89 sku AA0144 Cost = 42                         start time = Wed Jun 30 13:44:00 2021 , end time = Wed Jun 30 14:26:00 2021
# Worker 7 assigned to task 90 sku AA0145 Cost = 49                         start time = Wed Jun 30 13:22:00 2021 , end time = Wed Jun 30 14:11:00 2021
# Worker 8 assigned to task 91 sku AA0146 Cost = 54                         start time = Wed Jun 30 12:58:00 2021 , end time = Wed Jun 30 13:52:00 2021
# Worker 9 assigned to task 92 sku AA0147 Cost = 42                         start time = Wed Jun 30 13:21:00 2021 , end time = Wed Jun 30 14:03:00 2021
# Worker 10 assigned to task 93 sku AA0148 Cost = 44                         start time = Wed Jun 30 13:09:00 2021 , end time = Wed Jun 30 13:53:00 2021
# Worker 11 assigned to task 94 sku AA0149 Cost = 46                         start time = Wed Jun 30 12:55:00 2021 , end time = Wed Jun 30 13:41:00 2021
# Worker 12 assigned to task 95 sku AA0150 Cost = 53                         start time = Wed Jun 30 13:24:00 2021 , end time = Wed Jun 30 14:17:00 2021
# total tasks completed =  96 remaining task =  30
#
# Worker 1 assigned to task 96 sku AA0152 Cost = 45                         start time = Wed Jun 30 13:38:00 2021 , end time = Wed Jun 30 14:23:00 2021
# Worker 2 assigned to task 97 sku AA0155 Cost = 35                         start time = Wed Jun 30 13:57:00 2021 , end time = Wed Jun 30 14:32:00 2021
# Worker 3 assigned to task 98 sku AA0156 Cost = 53                         start time = Wed Jun 30 14:03:00 2021 , end time = Wed Jun 30 14:56:00 2021
# Worker 4 assigned to task 99 sku AA0158 Cost = 49                         start time = Wed Jun 30 14:19:00 2021 , end time = Wed Jun 30 15:08:00 2021
# Worker 5 assigned to task 100 sku AA0160 Cost = 43                         start time = Wed Jun 30 14:15:00 2021 , end time = Wed Jun 30 14:58:00 2021
# Worker 6 assigned to task 101 sku AA0161 Cost = 46                         start time = Wed Jun 30 14:26:00 2021 , end time = Wed Jun 30 15:12:00 2021
# Worker 7 assigned to task 102 sku AA0162 Cost = 40                         start time = Wed Jun 30 14:11:00 2021 , end time = Wed Jun 30 14:51:00 2021
# Worker 8 assigned to task 103 sku AA0164 Cost = 37                         start time = Wed Jun 30 13:52:00 2021 , end time = Wed Jun 30 14:29:00 2021
# Worker 9 assigned to task 104 sku AA0165 Cost = 35                         start time = Wed Jun 30 14:03:00 2021 , end time = Wed Jun 30 14:38:00 2021
# Worker 10 assigned to task 105 sku AA0166 Cost = 39                         start time = Wed Jun 30 13:53:00 2021 , end time = Wed Jun 30 14:32:00 2021
# Worker 11 assigned to task 106 sku AA0167 Cost = 39                         start time = Wed Jun 30 13:41:00 2021 , end time = Wed Jun 30 14:20:00 2021
# Worker 12 assigned to task 107 sku AA0171 Cost = 41                         start time = Wed Jun 30 14:17:00 2021 , end time = Wed Jun 30 14:58:00 2021
# total tasks completed =  108 remaining task =  18
#
# Worker 1 assigned to task 108 sku AA0172 Cost = 38                         start time = Wed Jun 30 14:23:00 2021 , end time = Wed Jun 30 15:01:00 2021
# Worker 2 assigned to task 109 sku AA0174 Cost = 37                         start time = Wed Jun 30 14:32:00 2021 , end time = Wed Jun 30 15:09:00 2021
# Worker 3 assigned to task 110 sku AA0175 Cost = 54                         start time = Wed Jun 30 14:56:00 2021 , end time = Wed Jun 30 15:50:00 2021
# Worker 4 assigned to task 111 sku AA0176 Cost = 47                         start time = Wed Jun 30 15:08:00 2021 , end time = Wed Jun 30 15:55:00 2021
# Worker 5 assigned to task 112 sku AA0177 Cost = 35                         start time = Wed Jun 30 14:58:00 2021 , end time = Wed Jun 30 15:33:00 2021
# Worker 6 assigned to task 113 sku AA0180 Cost = 47                         start time = Wed Jun 30 15:12:00 2021 , end time = Wed Jun 30 15:59:00 2021
# Worker 7 assigned to task 114 sku AA0185 Cost = 41                         start time = Wed Jun 30 14:51:00 2021 , end time = Wed Jun 30 15:32:00 2021
# Worker 8 assigned to task 115 sku AA0186 Cost = 43                         start time = Wed Jun 30 14:29:00 2021 , end time = Wed Jun 30 15:12:00 2021
# Worker 9 assigned to task 116 sku AA0187 Cost = 42                         start time = Wed Jun 30 14:38:00 2021 , end time = Wed Jun 30 15:20:00 2021
# Worker 10 assigned to task 117 sku AA0189 Cost = 49                         start time = Wed Jun 30 14:32:00 2021 , end time = Wed Jun 30 15:21:00 2021
# Worker 11 assigned to task 118 sku AA0191 Cost = 42                         start time = Wed Jun 30 14:20:00 2021 , end time = Wed Jun 30 15:02:00 2021
# Worker 12 assigned to task 119 sku AA0192 Cost = 38                         start time = Wed Jun 30 14:58:00 2021 , end time = Wed Jun 30 15:36:00 2021
# total tasks completed =  120 remaining task =  6
#
# Worker 1 assigned to task 120 sku AA0193 Cost = 41                         start time = Wed Jun 30 15:01:00 2021 end time = Wed Jun 30 15:42:00 2021
# Worker 2 assigned to task 121 sku AA0194 Cost = 36                         start time = Wed Jun 30 15:09:00 2021 end time = Wed Jun 30 15:45:00 2021
# Worker 3 assigned to task 122 sku AA0195 Cost = 49                         start time = Wed Jun 30 15:50:00 2021 end time = Wed Jun 30 16:39:00 2021
# Worker 4 assigned to task 123 sku AA0198 Cost = 42                         start time = Wed Jun 30 15:55:00 2021 end time = Wed Jun 30 16:37:00 2021
# Worker 5 assigned to task 124 sku AA0199 Cost = 43                         start time = Wed Jun 30 15:33:00 2021 end time = Wed Jun 30 16:16:00 2021
# Worker 6 assigned to task 125 sku AA0200 Cost = 40                         start time = Wed Jun 30 15:59:00 2021 end time = Wed Jun 30 16:39:00 2021
# total tasks completed =  126 remaining task =  0
